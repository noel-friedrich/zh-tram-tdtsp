# %%
"Timetable parsing"

from tramnetwork import *

lookup_day = "20250128"

network = TramNetwork()
network.load_day(lookup_day)
# Out:
# loaded routes.txt
# loaded transfers.txt
# loaded stops.txt
# loaded trips.txt
# loaded stop_times.txt
# loaded calendar.txt
# loaded calendar_dates.txt
# Found 203 Tram Stops (20250128).

# %%
"test timetable"

search_query = "Letzi"

time = gt_parse_time("13:33:00", lookup_day)
stop = network.search_stops(search_query)[0]
departures = stop.get_departures_after(time)
first_departure = departures[0]

print(f"Next Departure from {stop.name} is at {first_departure.departure_time} with {first_departure.tram_name}:")
print(first_departure)
# Out:
# Next Departure from Zürich, Letzistrasse is at 2025-01-28 13:35:18 with T10:
# [2025-01-28 13:35:06] Zürich, Letzistrasse           (T10) [2025-01-28 13:35:18]
# [2025-01-28 13:35:54] Zürich, Kinkelstrasse          (T10) [2025-01-28 13:36:06]
# [2025-01-28 13:37:00] Zürich, Seilbahn Rigiblick     (T10) [2025-01-28 13:37:18]
# [2025-01-28 13:38:12] Zürich, Winkelriedstrasse      (T10) [2025-01-28 13:38:24]
# [2025-01-28 13:39:18] Zürich, Haldenbach             (T10) [2025-01-28 13:39:30]
# [2025-01-28 13:40:48] Zürich, ETH/Universitätsspital (T10) [2025-01-28 13:41:06]
# [2025-01-28 13:42:24] Zürich, Haldenegg              (T10) [2025-01-28 13:42:36]
# [2025-01-28 13:44:12] Zürich, Central                (T10) [2025-01-28 13:44:36]
# [2025-01-28 13:46:30] Zürich, Bahnhofplatz/HB        (T10) [2025-01-28 13:46:30]

# %%
"pathfinding using dijkstra"

import bisect

MAX_TRANSITION_SECONDS = 30 * 60
MIN_CHANGE_BUFFER_SECONDS = 30

class NoConnectionsLeftException(Exception):
    pass

def calc_dijkstra_path_to(start_time: datetime, start: TramStop, destination_criterium,
                          start_tram: TramName=None, weight_func=None) -> TramPath:
    visited_stops = set()
    start_connection = TramPath([start], [start_time], [None], [None])
    visit_stack = [(0, start_time, start_connection, start)]

    while len(visit_stack) > 0:
        _, curr_time, prev_stops, stop = visit_stack.pop(0)
        if stop in visited_stops:
            continue

        visited_stops.add(stop)
        if destination_criterium(stop):
            return prev_stops

        connections = stop.get_departures_after(curr_time)
        for connection in connections:
            wait_seconds = (connection.arrival_time - curr_time).total_seconds()
            
            if len(prev_stops) >= 2:
                last_tram_name = prev_stops.transportation_names[-2]
            else:
                last_tram_name = start_tram

            if last_tram_name is not None and connection.tram_name != last_tram_name:
                # it's a change of tram!
                if wait_seconds < MIN_CHANGE_BUFFER_SECONDS:
                    continue

            if wait_seconds >= MAX_TRANSITION_SECONDS:
                break

            new_stop = connection.stops[1]
            new_time = connection.arrival_times[1]
            if new_stop in visited_stops:
                continue

            prev_stops_copy = prev_stops.slice(0)
            prev_stops_copy.stop_departure_times[-1] = connection.departure_time
            prev_stops_copy.transportation_names[-1] = connection.tram_name

            prev_stops_copy.add_stop(new_stop, new_time, None, None)
            
            weight = new_time.timestamp()
            if weight_func is not None:
                weight += weight_func(new_stop)

            bisect.insort(visit_stack, (weight, new_time, prev_stops_copy, new_stop))
            
    raise NoConnectionsLeftException("Couldn't find connection in time")

def calc_dijkstra_path_between(start_time: datetime, start: TramStop, destination: TramStop,
                               start_tram: TramName=None, weight_func=None) -> TramPath:
    destination_criterium = lambda stop: stop == destination
    return calc_dijkstra_path_to(start_time, start, destination_criterium, start_tram=start_tram, weight_func=weight_func)

stop1 = network.search_stops("Albis")[0]
stop2 = network.search_stops("Flug")[0]
start_time = gt_parse_time("12:00:00", lookup_day)

connection = calc_dijkstra_path_between(start_time, stop1, stop2)
connection.print_summary()
# Out:
# Start: Zürich, Albisgütli
# Destination: Zürich Flughafen, Bahnhof
# Total Time: 0:52:18
# Start Time: 2025-01-28 12:03:00
# Total Stops: 35

# %%
"nearest neighbour search"

def calc_nearest_neighbor_search(start_stop: TramStop, start_time: datetime, weight_func=None) -> TramPath:
    unvisited_stops = set(network.stops)
    unvisited_stops.remove(start_stop)
    destination_criterium = lambda stop: stop in unvisited_stops
    visit_count = 0

    curr_stop = start_stop
    curr_time = start_time
    path = TramPath()
    curr_tram = None
    while len(unvisited_stops) > 0:
        new_path = calc_dijkstra_path_to(curr_time, curr_stop, destination_criterium, start_tram=curr_tram, weight_func=weight_func)
        curr_time = new_path.arrival_times[-1]

        visit_count += 1
        path.add_path(new_path)
        curr_stop = path.stops[-1]
        curr_tram = path.transportation_names[-2]
        unvisited_stops.remove(curr_stop)

    return path

letzi = network.search_stops("Letzi")[0]
start_time = gt_parse_time("10:00:00", lookup_day)

nearest_neighbour_path = calc_nearest_neighbor_search(letzi, start_time)
nearest_neighbour_path.print_summary()
# Out:
# Start: Zürich, Letzistrasse
# Destination: Zürich, Wollishoferplatz
# Total Time: 10:43:12
# Start Time: 2025-01-28 10:00:18
# Total Stops: 374

# %%
"test loading old path"

best_path = TramPath.load("ant.2025-01-28--9-06-18.txt", network)

print(best_path)
# Out:
# [2025-01-28 09:00:00] Schlieren, Geissweid           (T2) [2025-01-28 09:05:48]
# [2025-01-28 09:07:00] Schlieren, Zentrum/Bahnhof     (T2) [2025-01-28 09:07:18]
# [2025-01-28 09:08:12] Schlieren, Wagonsfabrik        (T2) [2025-01-28 09:08:24]
# [2025-01-28 09:09:24] Schlieren, Gasometerbrücke     (T2) [2025-01-28 09:09:36]
# [2025-01-28 09:10:30] Schlieren, Mülligen            (T2) [2025-01-28 09:10:42]
# [2025-01-28 09:11:42] Zürich, Micafil                (T2) [2025-01-28 09:11:54]
# [2025-01-28 09:12:48] Zürich, Farbhof                (T2) [2025-01-28 09:13:00]
# [2025-01-28 09:13:54] Zürich, Bachmattstrasse        (T2) [2025-01-28 09:14:06]
# [2025-01-28 09:14:48] Zürich, Lindenplatz            (T2) [2025-01-28 09:15:12]
# [2025-01-28 09:16:06] Zürich, Grimselstrasse         (T2) [2025-01-28 09:16:24]
# [2025-01-28 09:17:36] Zürich, Kappeli                (T2) [2025-01-28 09:17:54]
# [2025-01-28 09:18:42] Zürich, Freihofstrasse         (T2) [2025-01-28 09:19:00]
# [2025-01-28 09:19:48] Zürich, Letzigrund             (T2) [2025-01-28 09:20:06]
# [2025-01-28 09:21:18] Zürich, Albisriederplatz B     (T3) [2025-01-28 09:27:42]
# [2025-01-28 09:28:24] Zürich, Altes Krematorium      (T3) [2025-01-28 09:28:36]
# [2025-01-28 09:29:42] Zürich, Hubertus               (T3) [2025-01-28 09:30:00]
# [2025-01-28 09:31:12] Zürich, Siemens                (T3) [2025-01-28 09:31:24]
# [2025-01-28 09:32:24] Zürich, Fellenbergstrasse      (T3) [2025-01-28 09:32:42]
# [2025-01-28 09:33:48] Zürich, Albisrieden            (T3) [2025-01-28 09:41:00]
# [2025-01-28 09:42:18] Zürich, Fellenbergstrasse      (T3) [2025-01-28 09:42:36]
# [2025-01-28 09:43:42] Zürich, Siemens                (T3) [2025-01-28 09:44:00]
# [2025-01-28 09:45:18] Zürich, Hubertus               (T3) [2025-01-28 09:45:36]
# [2025-01-28 09:46:48] Zürich, Altes Krematorium      (T3) [2025-01-28 09:47:00]
# [2025-01-28 09:47:48] Zürich, Albisriederplatz B     (T3) [2025-01-28 09:48:12]
# [2025-01-28 09:49:06] Zürich, Zypressenstrasse       (T3) [2025-01-28 09:49:18]
# [2025-01-28 09:50:06] Zürich, Lochergut              (T3) [2025-01-28 09:50:24]
# [2025-01-28 09:51:30] Zürich,Kalkbreite/Bhf.Wiedikon (T3) [2025-01-28 09:51:54]
# [2025-01-28 09:52:54] Zürich, Bezirksgebäude         (T3) [2025-01-28 09:53:12]
# [2025-01-28 09:54:30] Zürich, Stauffacher            (T9) [2025-01-28 09:58:24]
# [2025-01-28 09:59:24] Zürich, Werd                   (T9) [2025-01-28 09:59:36]
# [2025-01-28 10:00:36] Zürich, Bahnhof Wiedikon       (T9) [2025-01-28 10:01:00]
# [2025-01-28 10:02:24] Zürich, Schmiede Wiedikon      (T9) [2025-01-28 10:02:42]
# [2025-01-28 10:03:48] Zürich, Goldbrunnenplatz       (T9) [2025-01-28 10:04:06]
# [2025-01-28 10:05:00] Zürich, Talwiesenstrasse       (T9) [2025-01-28 10:05:18]
# [2025-01-28 10:05:54] Zürich, Heuried                (T14) [2025-01-28 10:10:18]
# [2025-01-28 10:11:06] Zürich, Schaufelbergerstrasse  (T14) [2025-01-28 10:11:18]
# [2025-01-28 10:12:30] Zürich, Triemli                (T14) [2025-01-28 10:17:30]
# [2025-01-28 10:19:00] Zürich, Schaufelbergerstrasse  (T14) [2025-01-28 10:19:18]
# [2025-01-28 10:20:12] Zürich, Heuried                (T14) [2025-01-28 10:20:24]
# [2025-01-28 10:21:00] Zürich, Talwiesenstrasse       (T14) [2025-01-28 10:21:18]
# [2025-01-28 10:22:12] Zürich, Goldbrunnenplatz       (T14) [2025-01-28 10:22:30]
# [2025-01-28 10:23:48] Zürich, Schmiede Wiedikon      (T14) [2025-01-28 10:24:18]
# [2025-01-28 10:25:42] Zürich, Bahnhof Wiedikon       (T14) [2025-01-28 10:26:00]
# [2025-01-28 10:26:54] Zürich, Werd                   (T14) [2025-01-28 10:27:06]
# [2025-01-28 10:28:06] Zürich, Stauffacher            (T8) [2025-01-28 10:35:36]
# [2025-01-28 10:36:48] Zürich, Helvetiaplatz          (T8) [2025-01-28 10:37:06]
# [2025-01-28 10:38:24] Zürich, Bäckeranlage           (T8) [2025-01-28 10:38:36]
# [2025-01-28 10:39:48] Zürich, Güterbahnhof           (T8) [2025-01-28 10:40:00]
# [2025-01-28 10:40:54] Zürich, Hardplatz              (T8) [2025-01-28 10:41:18]
# [2025-01-28 10:42:30] Zürich, Bahnhof Hardbrücke     (T8) [2025-01-28 10:43:00]
# [2025-01-28 10:44:18] Zürich, Schiffbau              (T4) [2025-01-28 10:50:48]
# [2025-01-28 10:51:48] Zürich, Technopark             (T4) [2025-01-28 10:52:00]
# [2025-01-28 10:52:48] Zürich, Toni-Areal             (T4) [2025-01-28 10:53:06]
# [2025-01-28 10:53:48] Zürich, Sportweg               (T4) [2025-01-28 10:54:00]
# [2025-01-28 10:54:42] Zürich, Aargauerstrasse        (T4) [2025-01-28 10:54:54]
# [2025-01-28 10:55:54] Zürich, Würzgraben             (T4) [2025-01-28 10:56:06]
# [2025-01-28 10:57:30] Zürich, Bahnhof Altstetten N K (T4) [2025-01-28 11:01:30]
# [2025-01-28 11:02:36] Zürich, Würzgraben             (T4) [2025-01-28 11:02:48]
# [2025-01-28 11:03:54] Zürich, Aargauerstrasse        (T4) [2025-01-28 11:04:06]
# [2025-01-28 11:05:00] Zürich, Sportweg               (T4) [2025-01-28 11:05:12]
# [2025-01-28 11:06:00] Zürich, Toni-Areal             (T4) [2025-01-28 11:06:18]
# [2025-01-28 11:07:06] Zürich, Technopark             (T4) [2025-01-28 11:07:24]
# [2025-01-28 11:08:36] Zürich, Schiffbau              (T4) [2025-01-28 11:08:54]
# [2025-01-28 11:10:30] Zürich, Escher-Wyss-Platz      (T17) [2025-01-28 11:13:54]
# [2025-01-28 11:15:36] Zürich, Förrlibuckstrasse      (T17) [2025-01-28 11:15:48]
# [2025-01-28 11:16:36] Zürich, Fischerweg             (T17) [2025-01-28 11:16:48]
# [2025-01-28 11:17:30] Zürich, Bernoulli-Häuser       (T17) [2025-01-28 11:17:42]
# [2025-01-28 11:18:36] Zürich, Hardturm               (T17) [2025-01-28 11:18:48]
# [2025-01-28 11:19:48] Zürich, Hardhof                (T17) [2025-01-28 11:20:00]
# [2025-01-28 11:20:42] Zürich, Tüffenwies             (T17) [2025-01-28 11:20:54]
# [2025-01-28 11:22:06] Zürich, Grünaustrasse          (T17) [2025-01-28 11:22:18]
# [2025-01-28 11:23:06] Zürich, Bändliweg              (T17) [2025-01-28 11:23:18]
# [2025-01-28 11:24:30] Zürich, Werdhölzli             (T17) [2025-01-28 11:32:00]
# [2025-01-28 11:32:48] Zürich, Bändliweg              (T17) [2025-01-28 11:33:00]
# [2025-01-28 11:33:54] Zürich, Grünaustrasse          (T17) [2025-01-28 11:34:06]
# [2025-01-28 11:35:24] Zürich, Tüffenwies             (T17) [2025-01-28 11:35:42]
# [2025-01-28 11:36:24] Zürich, Hardhof                (T17) [2025-01-28 11:36:36]
# [2025-01-28 11:37:42] Zürich, Hardturm               (T17) [2025-01-28 11:37:54]
# [2025-01-28 11:38:48] Zürich, Bernoulli-Häuser       (T17) [2025-01-28 11:39:00]
# [2025-01-28 11:39:42] Zürich, Fischerweg             (T17) [2025-01-28 11:39:54]
# [2025-01-28 11:40:48] Zürich, Förrlibuckstrasse      (T17) [2025-01-28 11:41:00]
# [2025-01-28 11:42:54] Zürich, Escher-Wyss-Platz      (T13) [2025-01-28 11:45:42]
# [2025-01-28 11:47:06] Zürich, Wipkingerplatz         (T13) [2025-01-28 11:47:18]
# [2025-01-28 11:48:36] Zürich, Waidfussweg            (T13) [2025-01-28 11:48:48]
# [2025-01-28 11:50:06] Zürich, Eschergutweg           (T13) [2025-01-28 11:50:18]
# [2025-01-28 11:51:24] Zürich, Alte Trotte            (T13) [2025-01-28 11:51:36]
# [2025-01-28 11:52:30] Zürich, Schwert                (T13) [2025-01-28 11:52:42]
# [2025-01-28 11:53:48] Zürich, Meierhofplatz          (T13) [2025-01-28 11:54:00]
# [2025-01-28 11:55:12] Zürich, Zwielplatz             (T13) [2025-01-28 11:55:24]
# [2025-01-28 11:56:24] Zürich, Wartau                 (T13) [2025-01-28 11:56:36]
# [2025-01-28 11:57:36] Zürich, Winzerstrasse          (T13) [2025-01-28 11:57:48]
# [2025-01-28 11:59:00] Zürich, Frankental             (T13) [2025-01-28 12:01:30]
# [2025-01-28 12:02:54] Zürich, Winzerstrasse          (T13) [2025-01-28 12:03:06]
# [2025-01-28 12:04:00] Zürich, Wartau                 (T13) [2025-01-28 12:04:12]
# [2025-01-28 12:05:12] Zürich, Zwielplatz             (T13) [2025-01-28 12:05:24]
# [2025-01-28 12:06:24] Zürich, Meierhofplatz          (T13) [2025-01-28 12:06:42]
# [2025-01-28 12:07:54] Zürich, Schwert                (T13) [2025-01-28 12:08:06]
# [2025-01-28 12:09:06] Zürich, Alte Trotte            (T13) [2025-01-28 12:09:18]
# [2025-01-28 12:10:30] Zürich, Eschergutweg           (T13) [2025-01-28 12:10:42]
# [2025-01-28 12:12:00] Zürich, Waidfussweg            (T13) [2025-01-28 12:12:18]
# [2025-01-28 12:13:30] Zürich, Wipkingerplatz         (T13) [2025-01-28 12:13:48]
# [2025-01-28 12:15:18] Zürich, Escher-Wyss-Platz      (T13) [2025-01-28 12:15:36]
# [2025-01-28 12:16:24] Zürich, Löwenbräu              (T13) [2025-01-28 12:16:36]
# [2025-01-28 12:17:18] Zürich, Quellenstrasse         (T13) [2025-01-28 12:17:30]
# [2025-01-28 12:18:18] Zürich, Limmatplatz            (T13) [2025-01-28 12:18:42]
# [2025-01-28 12:19:36] Zürich, Museum für Gestaltung  (T13) [2025-01-28 12:19:48]
# [2025-01-28 12:20:48] Zürich, Sihlquai/HB            (T13) [2025-01-28 12:21:06]
# [2025-01-28 12:23:12] Zürich, Bahnhofquai/HB         (T11) [2025-01-28 12:24:12]
# [2025-01-28 12:25:48] Zürich, Stampfenbachplatz      (T11) [2025-01-28 12:26:00]
# [2025-01-28 12:27:12] Zürich, Beckenhof              (T11) [2025-01-28 12:27:24]
# [2025-01-28 12:28:24] Zürich, Kronenstrasse          (T11) [2025-01-28 12:28:42]
# [2025-01-28 12:30:06] Zürich, Schaffhauserplatz      (T11) [2025-01-28 12:30:24]
# [2025-01-28 12:31:12] Zürich, Laubiweg               (T11) [2025-01-28 12:31:24]
# [2025-01-28 12:32:30] Zürich, Bucheggplatz C         (T11) [2025-01-28 12:33:00]
# [2025-01-28 12:34:00] Zürich, Brunnenhof             (T11) [2025-01-28 12:34:18]
# [2025-01-28 12:35:18] Zürich, Bad Allenmoos          (T11) [2025-01-28 12:35:30]
# [2025-01-28 12:36:12] Zürich, Regensbergbrücke       (T11) [2025-01-28 12:36:24]
# [2025-01-28 12:37:42] Zürich, Bahnhof Oerlikon Ost   (T11) [2025-01-28 12:38:06]
# [2025-01-28 12:39:24] Zürich, Sternen Oerlikon       (T11) [2025-01-28 12:39:42]
# [2025-01-28 12:40:42] Zürich, Messe/Hallenstadion    (T11) [2025-01-28 12:40:54]
# [2025-01-28 12:41:54] Zürich, Leutschenbach          (T11) [2025-01-28 12:42:06]
# [2025-01-28 12:42:48] Zürich, Oerlikerhus            (T11) [2025-01-28 12:43:00]
# [2025-01-28 12:44:12] Glattpark                      (T10) [2025-01-28 12:46:42]
# [2025-01-28 12:47:42] Glattpark, Lindberghplatz      (T10) [2025-01-28 12:48:00]
# [2025-01-28 12:49:12] Glattbrugg, Bahnhof            (T10) [2025-01-28 12:49:30]
# [2025-01-28 12:50:48] Rümlang, Bäuler                (T10) [2025-01-28 12:51:00]
# [2025-01-28 12:52:00] Glattbrugg, Unterriet          (T10) [2025-01-28 12:52:12]
# [2025-01-28 12:53:18] Kloten Balsberg, Bahnhof       (T10) [2025-01-28 12:53:30]
# [2025-01-28 12:55:18] Zürich Flughafen, Bahnhof      (T10) [2025-01-28 12:55:36]
# [2025-01-28 12:57:12] Zürich Flughafen, Fracht       (T12) [2025-01-28 13:00:30]
# [2025-01-28 13:01:48] Zürich Flughafen, Bahnhof      (T12) [2025-01-28 13:02:12]
# [2025-01-28 13:04:06] Kloten Balsberg, Bahnhof       (T12) [2025-01-28 13:04:18]
# [2025-01-28 13:05:24] Glattbrugg, Unterriet          (T12) [2025-01-28 13:05:36]
# [2025-01-28 13:06:36] Rümlang, Bäuler                (T12) [2025-01-28 13:06:48]
# [2025-01-28 13:08:00] Glattbrugg, Bahnhof            (T12) [2025-01-28 13:08:18]
# [2025-01-28 13:09:30] Glattpark, Lindberghplatz      (T12) [2025-01-28 13:09:48]
# [2025-01-28 13:11:24] Glattpark                      (T12) [2025-01-28 13:11:36]
# [2025-01-28 13:12:24] Zürich, Fernsehstudio          (T12) [2025-01-28 13:12:36]
# [2025-01-28 13:13:54] Zürich, Auzelg                 (T12) [2025-01-28 13:14:06]
# [2025-01-28 13:15:24] Wallisellen, Herti             (T12) [2025-01-28 13:15:42]
# [2025-01-28 13:17:06] Wallisellen, Belair            (T12) [2025-01-28 13:17:18]
# [2025-01-28 13:18:18] Wallisellen, Bahnhof           (T12) [2025-01-28 13:18:42]
# [2025-01-28 13:19:48] Wallisellen, Glatt (Tram)      (T12) [2025-01-28 13:20:06]
# [2025-01-28 13:21:24] Wallisellen, Neugut            (T12) [2025-01-28 13:21:36]
# [2025-01-28 13:22:48] Dübendorf, Am Ring             (T12) [2025-01-28 13:23:00]
# [2025-01-28 13:24:12] Dübendorf, Ringwiesen          (T12) [2025-01-28 13:24:24]
# [2025-01-28 13:26:48] Zürich, Bahnhof Stettbach      (T7) [2025-01-28 13:34:30]
# [2025-01-28 13:35:24] Zürich, Mattenhof              (T7) [2025-01-28 13:35:36]
# [2025-01-28 13:36:24] Zürich, Probstei               (T7) [2025-01-28 13:36:42]
# [2025-01-28 13:37:30] Zürich, Glattwiesen            (T7) [2025-01-28 13:37:42]
# [2025-01-28 13:38:36] Zürich, Roswiesen              (T7) [2025-01-28 13:38:48]
# [2025-01-28 13:40:00] Zürich, Schwamendingerplatz    (T9) [2025-01-28 13:47:12]
# [2025-01-28 13:48:12] Zürich, Heerenwiesen           (T9) [2025-01-28 13:48:24]
# [2025-01-28 13:49:12] Zürich, Luegisland             (T9) [2025-01-28 13:49:24]
# [2025-01-28 13:50:12] Zürich, Luchswiesen            (T9) [2025-01-28 13:50:30]
# [2025-01-28 13:51:18] Zürich, Altried                (T9) [2025-01-28 13:51:30]
# [2025-01-28 13:52:24] Zürich, Hirzenbach             (T9) [2025-01-28 13:59:30]
# [2025-01-28 14:00:36] Zürich, Altried                (T9) [2025-01-28 14:00:54]
# [2025-01-28 14:01:48] Zürich, Luchswiesen            (T9) [2025-01-28 14:02:06]
# [2025-01-28 14:02:54] Zürich, Luegisland             (T9) [2025-01-28 14:03:12]
# [2025-01-28 14:04:00] Zürich, Heerenwiesen           (T9) [2025-01-28 14:04:12]
# [2025-01-28 14:05:18] Zürich, Schwamendingerplatz    (T9) [2025-01-28 14:05:42]
# [2025-01-28 14:06:54] Zürich, Ueberlandpark          (T9) [2025-01-28 14:07:06]
# [2025-01-28 14:08:06] Zürich, Waldgarten             (T9) [2025-01-28 14:08:18]
# [2025-01-28 14:09:12] Zürich, Tierspital             (T9) [2025-01-28 14:09:24]
# [2025-01-28 14:11:06] Zürich, Milchbuck              (T9) [2025-01-28 14:11:36]
# [2025-01-28 14:12:42] Zürich, Universität Irchel     (T9) [2025-01-28 14:13:00]
# [2025-01-28 14:14:06] Zürich, Langmauerstrasse       (T9) [2025-01-28 14:14:18]
# [2025-01-28 14:15:06] Zürich, Letzistrasse           (T9) [2025-01-28 14:15:18]
# [2025-01-28 14:15:54] Zürich, Kinkelstrasse          (T9) [2025-01-28 14:16:06]
# [2025-01-28 14:17:00] Zürich, Seilbahn Rigiblick     (T9) [2025-01-28 14:17:18]
# [2025-01-28 14:18:12] Zürich, Winkelriedstrasse      (T9) [2025-01-28 14:18:24]
# [2025-01-28 14:19:18] Zürich, Haldenbach             (T9) [2025-01-28 14:19:30]
# [2025-01-28 14:20:42] Zürich, ETH/Universitätsspital (T9) [2025-01-28 14:21:00]
# [2025-01-28 14:22:18] Zürich, Kantonsschule          (T5) [2025-01-28 14:27:24]
# [2025-01-28 14:29:06] Zürich, Platte                 (T5) [2025-01-28 14:29:24]
# [2025-01-28 14:30:48] Zürich, Voltastrasse           (T5) [2025-01-28 14:31:00]
# [2025-01-28 14:32:30] Zürich, Kirche Fluntern        (T6) [2025-01-28 14:35:18]
# [2025-01-28 14:36:30] Zürich, Toblerplatz            (T6) [2025-01-28 14:36:48]
# [2025-01-28 14:37:42] Zürich, Zürichbergstrasse      (T6) [2025-01-28 14:37:54]
# [2025-01-28 14:38:36] Zürich, Susenbergstrasse       (T6) [2025-01-28 14:38:48]
# [2025-01-28 14:40:30] Zürich, Zoo                    (T6) [2025-01-28 14:42:00]
# [2025-01-28 14:43:24] Zürich, Susenbergstrasse       (T6) [2025-01-28 14:43:36]
# [2025-01-28 14:44:30] Zürich, Zürichbergstrasse      (T6) [2025-01-28 14:44:42]
# [2025-01-28 14:45:48] Zürich, Toblerplatz            (T6) [2025-01-28 14:46:06]
# [2025-01-28 14:47:24] Zürich, Kirche Fluntern        (T6) [2025-01-28 14:47:42]
# [2025-01-28 14:49:12] Zürich, Voltastrasse           (T6) [2025-01-28 14:49:24]
# [2025-01-28 14:50:54] Zürich, Platte                 (T6) [2025-01-28 14:51:12]
# [2025-01-28 14:53:24] Zürich, ETH/Universitätsspital (T6) [2025-01-28 14:53:42]
# [2025-01-28 14:55:00] Zürich, Haldenegg              (T6) [2025-01-28 14:55:12]
# [2025-01-28 14:56:48] Zürich, Central                (T4) [2025-01-28 14:58:18]
# [2025-01-28 14:59:12] Zürich, Rudolf-Brun-Brücke     (T4) [2025-01-28 14:59:30]
# [2025-01-28 15:00:06] Zürich, Rathaus                (T4) [2025-01-28 15:00:24]
# [2025-01-28 15:01:12] Zürich, Helmhaus               (T4) [2025-01-28 15:01:30]
# [2025-01-28 15:02:48] Zürich, Bellevue               (T4) [2025-01-28 15:03:12]
# [2025-01-28 15:04:18] Zürich, Opernhaus              (T4) [2025-01-28 15:04:42]
# [2025-01-28 15:05:30] Zürich, Kreuzstrasse           (T4) [2025-01-28 15:05:42]
# [2025-01-28 15:06:36] Zürich, Feldeggstrasse         (T4) [2025-01-28 15:06:54]
# [2025-01-28 15:07:42] Zürich, Höschgasse             (T4) [2025-01-28 15:08:00]
# [2025-01-28 15:09:00] Zürich, Fröhlichstrasse        (T4) [2025-01-28 15:09:12]
# [2025-01-28 15:09:54] Zürich, Wildbachstrasse        (T4) [2025-01-28 15:10:06]
# [2025-01-28 15:11:18] Zürich, Bahnhof Tiefenbrunnen  (T2) [2025-01-28 15:14:00]
# [2025-01-28 15:15:00] Zürich, Wildbachstrasse        (T2) [2025-01-28 15:15:12]
# [2025-01-28 15:15:54] Zürich, Fröhlichstrasse        (T2) [2025-01-28 15:16:12]
# [2025-01-28 15:17:06] Zürich, Höschgasse             (T2) [2025-01-28 15:17:24]
# [2025-01-28 15:18:06] Zürich, Feldeggstrasse         (T2) [2025-01-28 15:18:24]
# [2025-01-28 15:19:12] Zürich, Kreuzstrasse           (T2) [2025-01-28 15:19:30]
# [2025-01-28 15:20:36] Zürich, Opernhaus              (T2) [2025-01-28 15:21:00]
# [2025-01-28 15:22:30] Zürich, Bellevue               (T11) [2025-01-28 15:24:30]
# [2025-01-28 15:26:00] Zürich, Bahnhof Stadelhofen    (T11) [2025-01-28 15:26:30]
# [2025-01-28 15:27:48] Zürich, Kreuzplatz             (T11) [2025-01-28 15:28:06]
# [2025-01-28 15:28:54] Zürich, Signaustrasse          (T11) [2025-01-28 15:29:06]
# [2025-01-28 15:29:48] Zürich, Hegibachplatz B        (T11) [2025-01-28 15:30:06]
# [2025-01-28 15:31:06] Zürich, Hedwigsteig            (T11) [2025-01-28 15:31:18]
# [2025-01-28 15:31:54] Zürich, Wetlistrasse           (T11) [2025-01-28 15:32:06]
# [2025-01-28 15:32:48] Zürich, Burgwies               (T11) [2025-01-28 15:33:00]
# [2025-01-28 15:34:00] Zürich, Balgrist               (T11) [2025-01-28 15:34:18]
# [2025-01-28 15:35:30] Zürich, Friedhof Enzenbühl     (T11) [2025-01-28 15:35:42]
# [2025-01-28 15:36:36] Zürich, Rehalp                 (T11) [2025-01-28 15:37:30]
# [2025-01-28 15:38:18] Zürich, Friedhof Enzenbühl     (T11) [2025-01-28 15:38:30]
# [2025-01-28 15:39:54] Zürich, Balgrist               (T11) [2025-01-28 15:40:18]
# [2025-01-28 15:41:30] Zürich, Burgwies               (T11) [2025-01-28 15:41:42]
# [2025-01-28 15:42:30] Zürich, Wetlistrasse           (T11) [2025-01-28 15:42:42]
# [2025-01-28 15:43:24] Zürich, Hedwigsteig            (T11) [2025-01-28 15:43:36]
# [2025-01-28 15:44:36] Zürich, Hegibachplatz B        (T11) [2025-01-28 15:44:54]
# [2025-01-28 15:45:42] Zürich, Signaustrasse          (T11) [2025-01-28 15:45:54]
# [2025-01-28 15:47:00] Zürich, Kreuzplatz             (T8) [2025-01-28 15:54:18]
# [2025-01-28 15:55:18] Zürich, Englischviertelstrasse (T8) [2025-01-28 15:55:30]
# [2025-01-28 15:56:12] Zürich, Römerhof               (T8) [2025-01-28 15:56:30]
# [2025-01-28 15:57:18] Zürich, Hölderlinstrasse       (T8) [2025-01-28 15:57:30]
# [2025-01-28 15:59:00] Zürich, Klusplatz A            (T8) [2025-01-28 16:01:00]
# [2025-01-28 16:02:12] Zürich, Hölderlinstrasse       (T8) [2025-01-28 16:02:24]
# [2025-01-28 16:03:18] Zürich, Römerhof               (T3) [2025-01-28 16:05:06]
# [2025-01-28 16:06:12] Zürich, Hottingerplatz         (T3) [2025-01-28 16:06:36]
# [2025-01-28 16:08:18] Zürich, Kunsthaus              (T3) [2025-01-28 16:08:42]
# [2025-01-28 16:09:36] Zürich, Neumarkt               (T3) [2025-01-28 16:10:00]
# [2025-01-28 16:11:54] Zürich, Central                (T3) [2025-01-28 16:12:24]
# [2025-01-28 16:14:18] Zürich, Bahnhofplatz/HB        (T3) [2025-01-28 16:14:48]
# [2025-01-28 16:15:48] Zürich, Löwenplatz             (T3) [2025-01-28 16:16:12]
# [2025-01-28 16:17:30] Zürich, Sihlpost / HB          (T3) [2025-01-28 16:18:00]
# [2025-01-28 16:19:42] Zürich, Stauffacher            (T2) [2025-01-28 16:22:00]
# [2025-01-28 16:23:36] Zürich, Sihlstrasse            (T2) [2025-01-28 16:23:54]
# [2025-01-28 16:25:24] Zürich, Paradeplatz            (T2) [2025-01-28 16:25:48]
# [2025-01-28 16:26:36] Zürich, Kantonalbank           (T2) [2025-01-28 16:26:48]
# [2025-01-28 16:28:18] Zürich, Bürkliplatz            (T5) [2025-01-28 16:30:12]
# [2025-01-28 16:32:36] Zürich, Rentenanstalt          (T5) [2025-01-28 16:32:54]
# [2025-01-28 16:34:12] Zürich, Bahnhof Enge           (T7) [2025-01-28 16:35:36]
# [2025-01-28 16:36:30] Zürich, Museum Rietberg        (T7) [2025-01-28 16:36:42]
# [2025-01-28 16:37:42] Zürich, Brunaustrasse          (T7) [2025-01-28 16:37:54]
# [2025-01-28 16:38:54] Zürich, Billoweg               (T7) [2025-01-28 16:39:06]
# [2025-01-28 16:40:00] Zch, Bhf.Wollishofen/Staubstr. (T7) [2025-01-28 16:40:12]
# [2025-01-28 16:40:54] Zürich, Renggerstrasse         (T7) [2025-01-28 16:41:06]
# [2025-01-28 16:42:12] Zürich, Morgental              (T7) [2025-01-28 16:42:30]
# [2025-01-28 16:43:18] Zürich, Butzenstrasse          (T7) [2025-01-28 16:43:36]
# [2025-01-28 16:44:36] Zürich, Wollishoferplatz       (T7) [2025-01-28 16:50:00]
# [2025-01-28 16:51:24] Zürich, Butzenstrasse          (T7) [2025-01-28 16:51:42]
# [2025-01-28 16:52:36] Zürich, Morgental              (T7) [2025-01-28 16:52:54]
# [2025-01-28 16:54:06] Zürich, Renggerstrasse         (T7) [2025-01-28 16:54:24]
# [2025-01-28 16:55:12] Zch, Bhf.Wollishofen/Staubstr. (T7) [2025-01-28 16:55:30]
# [2025-01-28 16:56:30] Zürich, Billoweg               (T7) [2025-01-28 16:56:48]
# [2025-01-28 16:57:54] Zürich, Brunaustrasse          (T7) [2025-01-28 16:58:12]
# [2025-01-28 16:59:18] Zürich, Museum Rietberg        (T7) [2025-01-28 16:59:36]
# [2025-01-28 17:00:42] Zürich, Bahnhof Enge           (T7) [2025-01-28 17:01:12]
# [2025-01-28 17:02:18] Zürich, Tunnelstrasse          (T6) [2025-01-28 17:03:00]
# [2025-01-28 17:04:18] Zürich, Bahnhof Enge           (T5) [2025-01-28 17:05:36]
# [2025-01-28 17:06:42] Zürich, Bahnhof Enge/Bederstr. (T5) [2025-01-28 17:07:00]
# [2025-01-28 17:08:12] Zürich, Waffenplatzstrasse     (T5) [2025-01-28 17:08:24]
# [2025-01-28 17:09:06] Zürich, Sihlcity Nord          (T5) [2025-01-28 17:09:24]
# [2025-01-28 17:10:30] Zürich, Saalsporthalle         (T5) [2025-01-28 17:10:42]
# [2025-01-28 17:11:24] Zürich, Laubegg                (T17) [2025-01-28 17:13:12]
# [2025-01-28 17:14:24] Zürich, Uetlihof               (T17) [2025-01-28 17:14:42]
# [2025-01-28 17:15:42] Zürich, Strassenverkehrsamt    (T17) [2025-01-28 17:16:00]
# [2025-01-28 17:17:00] Zürich, Albisgütli             (T13) [2025-01-28 17:18:00]
# [2025-01-28 17:19:24] Zürich, Strassenverkehrsamt    (T13) [2025-01-28 17:19:42]
# [2025-01-28 17:21:00] Zürich, Uetlihof               (T13) [2025-01-28 17:21:18]
# [2025-01-28 17:22:30] Zürich, Laubegg                (T13) [2025-01-28 17:22:48]
# [2025-01-28 17:23:36] Zürich, Saalsporthalle         (T13) [2025-01-28 17:23:48]
# [2025-01-28 17:24:54] Zürich, Sihlcity Nord          (T13) [2025-01-28 17:25:12]
# [2025-01-28 17:26:30] Zürich, Waffenplatzstrasse     (T13) [2025-01-28 17:26:48]
# [2025-01-28 17:27:42] Zürich, Bahnhof Enge/Bederstr. (T13) [2025-01-28 17:28:00]
# [2025-01-28 17:29:00] Zürich, Tunnelstrasse          (T13) [2025-01-28 17:29:18]
# [2025-01-28 17:30:18] Zürich, Stockerstrasse         (T8) [2025-01-28 17:32:06]
# [2025-01-28 17:33:24] Zürich, Bahnhof Selnau         (T8) [2025-01-28 17:34:54]
# [2025-01-28 17:36:42] Zürich, Stockerstrasse         (T8) [2025-01-28 17:37:00]
# [2025-01-28 17:38:12] Zürich, Paradeplatz            (T13) [2025-01-28 17:39:48]
# [2025-01-28 17:41:06] Zürich, Rennweg                (T13) [2025-01-28 17:41:30]
# [2025-01-28 17:42:36] Zürich, Bahnhofstrasse/HB      (T6) [2025-01-28 17:44:06]
# [2025-01-28 17:46:30] Zürich, Central                (T6) [2025-01-28 17:46:54]
# [2025-01-28 17:48:36] Zürich, Haldenegg              (T7) [2025-01-28 17:51:30]
# [2025-01-28 17:52:18] Zürich, Sonneggstrasse         (T7) [2025-01-28 17:52:30]
# [2025-01-28 17:53:12] Zürich, Ottikerstrasse         (T7) [2025-01-28 17:53:24]
# [2025-01-28 17:54:18] Zürich, Röslistrasse           (T7) [2025-01-28 17:54:30]
# [2025-01-28 17:55:54] Zürich, Schaffhauserplatz      (T7) [2025-01-28 17:56:12]
# [2025-01-28 17:57:06] Zürich, Guggachstrasse         (T7) [2025-01-28 17:57:24]
# [2025-01-28 17:58:24] Zürich, Milchbuck              (T14) [2025-01-28 18:01:06]
# [2025-01-28 18:02:00] Zürich, Hirschwiesenstrasse    (T14) [2025-01-28 18:02:12]
# [2025-01-28 18:03:12] Zürich, Berninaplatz           (T14) [2025-01-28 18:03:30]
# [2025-01-28 18:04:12] Zürich, Salersteig             (T14) [2025-01-28 18:04:30]
# [2025-01-28 18:05:42] Zürich, Sternen Oerlikon       (T14) [2025-01-28 18:06:12]
# [2025-01-28 18:07:48] Zürich, Bahnhof Oerlikon Ost   (T14) [2025-01-28 18:08:12]
# [2025-01-28 18:09:06] Zürich, Felsenrainstrasse      (T14) [2025-01-28 18:09:24]
# [2025-01-28 18:10:24] Zürich, Seebacherplatz         (T14) [2025-01-28 18:10:48]
# [2025-01-28 18:12:06] Zürich, Seebach

# %%
"calc stop-heuristics for later optimization"

import random

heuristic_map: dict[TramStop, dict[str, float]] = {}
neighbour_map: dict[TramStop, set[TramStop]] = {}

min_connections = min(len(s.connections) for s in network.stops)
max_connections = max(len(s.connections) for s in network.stops)

min_lat = min(s.coords[0] for s in network.stops)
min_lon = min(s.coords[1] for s in network.stops)
max_lat = max(s.coords[0] for s in network.stops)
max_lon = max(s.coords[1] for s in network.stops)

for stop in network.stops:
    heuristics = {}

    neighbour_map[stop] = set(c.stops[1] for c in stop.connections) - set([stop])
    heuristics["popularity"] = len(neighbour_map[stop])
    heuristics["connectivity"] = (len(stop.connections) - min_connections) / (max_connections - min_connections)
    heuristics["spider-leg"] = 1 if heuristics["popularity"] == 1 else 0
    heuristics["distance_sum"] = sum(
        1 / (haversine_distance(stop.coords, other.coords) * 10) ** 2
        for other in network.stops if stop != other 
    )
    heuristics["lat"] = (stop.coords[0] - min_lat) / (max_lat - min_lat)
    heuristics["lon"] = (stop.coords[1] - min_lon) / (max_lon - min_lon)
    heuristics["random"] = random.random()

    heuristic_map[stop] = heuristics

for i in range(len(network.stops)):
    for stop in network.stops:
        neighbours = neighbour_map[stop]
        if len(neighbours) != 2:
            continue
        if any(heuristic_map[n]["spider-leg"] for n in neighbours):
            heuristic_map[stop]["spider-leg"] = 1

heuristic_names = list(list(heuristic_map.values())[0].keys())

# %%
"create network graph export"

import json

stop_id_map = dict([(stop, i) for i, stop in enumerate(network.stops)])

def time_to_dict(time: datetime) -> dict:
    return {
        "isotime": time.isoformat(),
        "timestamp": int(time.timestamp())
    }

def tram_to_dict(tram: TramName) -> dict:
    return {
        "name": tram.name,
        "uid": tram.uid
    }

def stop_to_dict(stop: TramStop, with_edges=True) -> dict:
    data = {}
    data["id"] = stop_id_map[stop]
    data["name"] = stop.name

    if with_edges:
        data |= {
            "id": stop_id_map[stop],
            "name": stop.name,
            "connections": [
                {
                    "arrival_timestamp": int(connection.arrival_time.timestamp()),
                    "departure_timestamp": int(connection.departure_time.timestamp()),
                    "next_stop_id": stop_id_map[connection.stops[1]],
                    "next_stop_arrival_timestamp": int(connection.arrival_times[1].timestamp()),
                    "tram": tram_to_dict(connection.tram_name),
                }
                for connection in stop.connections
            ],
            "lat": stop.coords[0],
            "lon": stop.coords[1]
        }

    return data

stations = []
for stop in network.stops:
    stations.append(stop_to_dict(stop))

with open("graph-exports/graph2.txt", "r") as file:
    distances = json.load(file)["distance_matrix"]

data = {
    "num_stops": len(network.stops),
    "num_edges": sum(len(s.connections) for s in network.stops),
    "date": time_to_dict(gt_parse_date(lookup_day)),
    "precomputed_distance_matrix": [[int(c) for c in r] for r in distances],
    "stops": stations
}

filename = "graph3.json"
file_path = os.path.join("graph-exports", filename)
with open(file_path, "w", encoding="utf-8") as file:
    json.dump(data, file, indent=4)

print(f"Exported Network as {file_path!r}")
# Out:
# Exported Network as 'graph-exports\\graph3.json'

# %%
"time dependant ant colony optimization"

import json
from functools import cache

precomputed_distance_matrix: dict[TramStop, dict[TramStop, float]] = {}
with open("graph-exports/graph2.txt", "r") as file:
    distances = json.load(file)["distance_matrix"]
    precomputed_distance_matrix = {
        stop1: {
            stop2: distances[i][j]
            for j, stop2 in enumerate(network.stops)
        }
        for i, stop1 in enumerate(network.stops)
    }

pheromone_map: dict[TramStop, dict[TramStop, float]] = None

def reset_pheromone_map():
    global pheromone_map
    pheromone_map = {
        stop1: {stop2: 1. for stop2 in network.stops}
        for stop1 in network.stops
    }

best_ant_path: TramPath = None

@cache
def get_path(t: datetime, a: TramStop, b: TramStop, c: TramName) -> TramPath:
    return calc_dijkstra_path_between(t, a, b, start_tram=c)

def ant_colony_opt(start_time: datetime, start_stop: TramStop, num_ants=50, generations=100,
                   reset_pheromones=True, pheromone_strength=0.01, pheromone_decay_factor=0.9,
                   min_pheromone=0.1, distance_power=2):
    global best_ant_path
    if pheromone_map is None or reset_pheromones:
        reset_pheromone_map()

    def simulate_ant(ant_index: int) -> TramPath:
        curr_path = TramPath()
        curr_path.add_stop(start_stop, start_time)
        curr_tram = None
        decisions = []

        print(f"> simulating ant#{(ant_index + 1):03}", end="\r")
        
        remaining_stops = set(network.stops) - set(curr_path.stops)
        while len(remaining_stops) > 0:
            curr_stop = curr_path.stops[-1]
            curr_time = curr_path.arrival_times[-1]

            available_stops = list(remaining_stops)
            available_weights = [
                pheromone_map[curr_stop][stop] * 100000
                / (precomputed_distance_matrix[curr_stop][stop] ** distance_power)
                for stop in available_stops
            ]

            new_stop = random_choice_distribution(available_stops, available_weights)

            try:
                new_path = get_path(
                    curr_path.arrival_times[-1],
                    curr_stop,
                    new_stop,
                    curr_tram
                )
            except NoConnectionsLeftException:
                return None
            
            decisions.append((curr_stop, new_stop, curr_time))
            curr_path.add_path(new_path)
            curr_tram = curr_path.transportation_names[-2]

            for stop in new_path.stops:
                if stop in remaining_stops:
                    remaining_stops.remove(stop)

        return curr_path, decisions

    print(f"Starting Ant Colony Optimization. {num_ants=} {generations=}")
    for gen_index in range(generations):

        # simulate all the ants
        ant_paths: list[TramPath] = []
        ant_decision_list: list[list[tuple[TramStop, TramStop, datetime]]] = []

        for ant_index in range(num_ants):
            ant_result = simulate_ant(ant_index)
            if ant_result is not None:
                ant_path, ant_decisions = ant_result
                ant_paths.append(ant_path)
                ant_decision_list.append(ant_decisions)

        # drop pheromones based on ant paths
        print("> dropping pheromones from ants", end="\r")
        for ant_path, ant_decisions in zip(ant_paths, ant_decision_list):
            path_seconds = ant_path.time_delta().total_seconds()
            pheromone_drop = pheromone_strength * len(network.stops) / path_seconds
            for sstop, end_stop, _ in ant_decisions:
                pheromone_map[sstop][end_stop] += pheromone_drop

            if best_ant_path is None or path_seconds < best_ant_path.time_delta().total_seconds():
                best_ant_path = ant_path
                best_ant_path.save("ant2-night")

        # decay pheromones a bit 
        print("> decaying all pheromones a bit", end="\r")
        for stop1 in network.stops:
            for stop2 in network.stops:
                val = pheromone_map[stop1][stop2]
                pheromone_map[stop1][stop2] = max(min_pheromone, val * pheromone_decay_factor)

        print(f"Gen{gen_index + 1:03}: best={best_ant_path.time_delta()} survivors={len(ant_paths)}")

    return best_ant_path

MIN_CHANGE_BUFFER_SECONDS = 30

ant_colony_opt(
    gt_parse_time("9:00:00", lookup_day),
    network.search_stops("Bahnhofplatz/HB")[0],
    num_ants=200,
    generations=999999999,
    reset_pheromones=True,
    pheromone_strength=50,
    pheromone_decay_factor=0.9,
    min_pheromone=0.1,
    distance_power=2
)
# Out:
# Starting Ant Colony Optimization. num_ants=200 generations=999999999
# Gen001: best=12:17:18 survivors=173
# Gen002: best=10:44:00 survivors=200
# Gen003: best=10:41:12 survivors=200
# Gen004: best=10:38:18 survivors=200
# Gen005: best=10:25:12 survivors=200
# Gen006: best=10:14:48 survivors=200
# Gen007: best=10:14:48 survivors=200
# Gen008: best=10:14:48 survivors=200
# Gen009: best=9:46:00 survivors=200
# Gen010: best=9:46:00 survivors=200
# Gen011: best=9:46:00 survivors=200
# Gen012: best=9:46:00 survivors=200
# Gen013: best=9:46:00 survivors=200
# Gen014: best=9:46:00 survivors=200
# Gen015: best=9:46:00 survivors=200
# Gen016: best=9:46:00 survivors=200
# Gen017: best=9:46:00 survivors=200
# Gen018: best=9:33:06 survivors=200
# Gen019: best=9:33:06 survivors=200
# Gen020: best=9:33:06 survivors=200
# Gen021: best=9:33:06 survivors=200
# Gen022: best=9:33:06 survivors=200
# Gen023: best=9:33:06 survivors=200
# Gen024: best=9:33:06 survivors=200
# Gen025: best=9:33:06 survivors=200
# Gen026: best=9:33:06 survivors=200
# Gen027: best=9:33:06 survivors=200
# Gen028: best=9:33:06 survivors=200
# Gen029: best=9:33:06 survivors=200
# Gen030: best=9:33:06 survivors=200
# Gen031: best=9:33:06 survivors=200
# Gen032: best=9:33:06 survivors=200
# Gen033: best=9:33:06 survivors=200
# Gen034: best=9:33:06 survivors=200
# Gen035: best=9:33:06 survivors=200
# Gen036: best=9:33:06 survivors=200
# Gen037: best=9:33:06 survivors=200
# Gen038: best=9:33:06 survivors=200
# Gen039: best=9:33:06 survivors=200
# Gen040: best=9:33:06 survivors=200
# Gen041: best=9:33:06 survivors=200
# Gen042: best=9:33:06 survivors=200
# Gen043: best=9:33:06 survivors=200
# Gen044: best=9:33:06 survivors=200
# Gen045: best=9:33:06 survivors=200
# Gen046: best=9:33:06 survivors=200
# Gen047: best=9:33:06 survivors=200
# Gen048: best=9:33:06 survivors=200
# Gen049: best=9:33:06 survivors=200
# Gen050: best=9:33:06 survivors=200
# Gen051: best=9:33:06 survivors=200
# Gen052: best=9:33:06 survivors=200
# Gen053: best=9:33:06 survivors=200
# Gen054: best=9:33:06 survivors=200
# Gen055: best=9:33:06 survivors=200
# Gen056: best=9:33:06 survivors=200
# Gen057: best=9:33:06 survivors=200
# Gen058: best=9:33:06 survivors=200
# Gen059: best=9:33:06 survivors=200
# Gen060: best=9:33:06 survivors=200
# Gen061: best=9:33:06 survivors=200
# Gen062: best=9:33:06 survivors=200
# Gen063: best=9:33:06 survivors=200
# Gen064: best=9:33:06 survivors=200
# Gen065: best=9:33:06 survivors=200
# Gen066: best=9:33:06 survivors=200
# Gen067: best=9:33:06 survivors=200
# Gen068: best=9:33:06 survivors=200
# Gen069: best=9:33:06 survivors=200
# Gen070: best=9:33:06 survivors=200
# Gen071: best=9:33:06 survivors=200
# Gen072: best=9:33:06 survivors=200
# Gen073: best=9:33:06 survivors=200
# Gen074: best=9:33:06 survivors=200
# Gen075: best=9:33:06 survivors=200
# Gen076: best=9:33:06 survivors=200
# Gen077: best=9:33:06 survivors=200
# Gen078: best=9:33:06 survivors=200
# Gen079: best=9:33:06 survivors=200
# Gen080: best=9:33:06 survivors=200
# Gen081: best=9:33:06 survivors=200
# Gen082: best=9:33:06 survivors=200
# Gen083: best=9:33:06 survivors=200
# Gen084: best=9:33:06 survivors=200
# Gen085: best=9:33:06 survivors=200
# Gen086: best=9:33:06 survivors=200
# Gen087: best=9:33:06 survivors=200
# Gen088: best=9:33:06 survivors=200
# Gen089: best=9:33:06 survivors=200
# Gen090: best=9:33:06 survivors=200
# Gen091: best=9:33:06 survivors=200
# Gen092: best=9:33:06 survivors=200
# Gen093: best=9:33:06 survivors=200
# Gen094: best=9:33:06 survivors=200
# Gen095: best=9:33:06 survivors=200
# Gen096: best=9:33:06 survivors=200
# Gen097: best=9:33:06 survivors=200
# Gen098: best=9:33:06 survivors=200
# Gen099: best=9:33:06 survivors=200
# Gen100: best=9:33:06 survivors=200
# Gen101: best=9:33:06 survivors=200
# Gen102: best=9:33:06 survivors=200
# Gen103: best=9:33:06 survivors=200
# Gen104: best=9:33:06 survivors=200
# Gen105: best=9:33:06 survivors=200
# Gen106: best=9:33:06 survivors=200
# Gen107: best=9:33:06 survivors=200
# Gen108: best=9:33:06 survivors=200
# Gen109: best=9:33:06 survivors=200
# Gen110: best=9:33:06 survivors=200
# Gen111: best=9:33:06 survivors=200
# Gen112: best=9:33:06 survivors=200
# Gen113: best=9:33:06 survivors=200
# Gen114: best=9:33:06 survivors=200
# Gen115: best=9:33:06 survivors=200
# Gen116: best=9:33:06 survivors=200
# Gen117: best=9:33:06 survivors=200
# Gen118: best=9:33:06 survivors=200
# Gen119: best=9:33:06 survivors=200
# Gen120: best=9:33:06 survivors=200
# Gen121: best=9:33:06 survivors=200
# Gen122: best=9:33:06 survivors=200
# Gen123: best=9:33:06 survivors=200
# Gen124: best=9:33:06 survivors=200
# Gen125: best=9:33:06 survivors=200
# Gen126: best=9:33:06 survivors=200
# Gen127: best=9:33:06 survivors=200
# Gen128: best=9:33:06 survivors=200
# Gen129: best=9:33:06 survivors=200
# Gen130: best=9:33:06 survivors=200
# Gen131: best=9:33:06 survivors=200
# Gen132: best=9:33:06 survivors=200
# Gen133: best=9:33:06 survivors=200
# Gen134: best=9:33:06 survivors=200
# Gen135: best=9:33:06 survivors=200
# Gen136: best=9:33:06 survivors=200
# Gen137: best=9:33:06 survivors=200
# Gen138: best=9:33:06 survivors=200
# Gen139: best=9:33:06 survivors=200
# Gen140: best=9:33:06 survivors=200
# Gen141: best=9:33:06 survivors=200
# Gen142: best=9:33:06 survivors=200
# Gen143: best=9:33:06 survivors=200
# Gen144: best=9:33:06 survivors=200
# Gen145: best=9:33:06 survivors=200
# Gen146: best=9:33:06 survivors=200
# Gen147: best=9:33:06 survivors=200
# Gen148: best=9:33:06 survivors=200
# Gen149: best=9:33:06 survivors=200
# Gen150: best=9:33:06 survivors=200
# Gen151: best=9:33:06 survivors=200
# Gen152: best=9:33:06 survivors=200
# Gen153: best=9:33:06 survivors=200
# Gen154: best=9:33:06 survivors=200
# Gen155: best=9:33:06 survivors=200
# Gen156: best=9:33:06 survivors=200
# Gen157: best=9:33:06 survivors=200
# Gen158: best=9:33:06 survivors=200
# Gen159: best=9:33:06 survivors=200
# Gen160: best=9:33:06 survivors=200
# Gen161: best=9:33:06 survivors=200
# Gen162: best=9:33:06 survivors=200
# Gen163: best=9:33:06 survivors=200
# Gen164: best=9:33:06 survivors=200
# Gen165: best=9:33:06 survivors=200
# Gen166: best=9:33:06 survivors=200
# Gen167: best=9:33:06 survivors=200
# Gen168: best=9:33:06 survivors=200
# Gen169: best=9:33:06 survivors=200
# Gen170: best=9:33:06 survivors=200
# Gen171: best=9:33:06 survivors=200
# Gen172: best=9:33:06 survivors=200
# Gen173: best=9:33:06 survivors=200
# Gen174: best=9:33:06 survivors=200
# Gen175: best=9:33:06 survivors=200
# Gen176: best=9:33:06 survivors=200
# Gen177: best=9:33:06 survivors=200
# Gen178: best=9:33:06 survivors=200
# Gen179: best=9:33:06 survivors=200
# Gen180: best=9:33:06 survivors=200
# Gen181: best=9:33:06 survivors=200
# Gen182: best=9:33:06 survivors=200
# Gen183: best=9:33:06 survivors=200
# Gen184: best=9:33:06 survivors=200
# Gen185: best=9:33:06 survivors=200
# Gen186: best=9:33:06 survivors=200
# Gen187: best=9:33:06 survivors=200
# Gen188: best=9:33:06 survivors=200
# Gen189: best=9:33:06 survivors=200
# Gen190: best=9:33:06 survivors=200
# Gen191: best=9:33:06 survivors=200
# Gen192: best=9:33:06 survivors=200
# Gen193: best=9:33:06 survivors=200
# Gen194: best=9:33:06 survivors=200
# Gen195: best=9:33:06 survivors=200
# Gen196: best=9:33:06 survivors=200
# Gen197: best=9:33:06 survivors=200
# Gen198: best=9:33:06 survivors=200
# Gen199: best=9:33:06 survivors=200
# Gen200: best=9:33:06 survivors=200
# Gen201: best=9:33:06 survivors=200
# Gen202: best=9:33:06 survivors=200
# Gen203: best=9:33:06 survivors=200
# Gen204: best=9:33:06 survivors=200
# Gen205: best=9:33:06 survivors=200
# Gen206: best=9:33:06 survivors=200
# Gen207: best=9:33:06 survivors=200
# Gen208: best=9:33:06 survivors=200
# Gen209: best=9:33:06 survivors=200
# Gen210: best=9:33:06 survivors=200
# Gen211: best=9:33:06 survivors=200
# Gen212: best=9:33:06 survivors=200
# Gen213: best=9:33:06 survivors=200
# Gen214: best=9:33:06 survivors=200
# Gen215: best=9:33:06 survivors=200
# Gen216: best=9:33:06 survivors=200
# Gen217: best=9:33:06 survivors=200
# Gen218: best=9:33:06 survivors=200
# Gen219: best=9:33:06 survivors=200
# Gen220: best=9:33:06 survivors=200
# Gen221: best=9:33:06 survivors=200
# Gen222: best=9:33:06 survivors=200
# Gen223: best=9:33:06 survivors=200
# Gen224: best=9:33:06 survivors=200
# Gen225: best=9:33:06 survivors=200
# Gen226: best=9:33:06 survivors=200
# Gen227: best=9:33:06 survivors=200
# Gen228: best=9:33:06 survivors=200
# Gen229: best=9:33:06 survivors=200
# Gen230: best=9:33:06 survivors=200
# Gen231: best=9:33:06 survivors=200
# Gen232: best=9:33:06 survivors=200
# Gen233: best=9:33:06 survivors=200
# Gen234: best=9:33:06 survivors=200
# Gen235: best=9:33:06 survivors=200
# Gen236: best=9:33:06 survivors=200
# Gen237: best=9:33:06 survivors=200
# Gen238: best=9:33:06 survivors=200
# Gen239: best=9:33:06 survivors=200
# Gen240: best=9:33:06 survivors=200
# Gen241: best=9:33:06 survivors=200
# Gen242: best=9:33:06 survivors=200
# Gen243: best=9:33:06 survivors=200
# Gen244: best=9:33:06 survivors=200
# Gen245: best=9:33:06 survivors=200
# Gen246: best=9:33:06 survivors=200
# Gen247: best=9:33:06 survivors=200
# Gen248: best=9:33:06 survivors=200
# Gen249: best=9:33:06 survivors=200
# Gen250: best=9:33:06 survivors=200
# Gen251: best=9:33:06 survivors=200
# Gen252: best=9:33:06 survivors=200
# Gen253: best=9:33:06 survivors=200
# Gen254: best=9:33:06 survivors=200
# Gen255: best=9:33:06 survivors=200
# Gen256: best=9:33:06 survivors=200
# Gen257: best=9:33:06 survivors=200
# Gen258: best=9:33:06 survivors=200
# Gen259: best=9:33:06 survivors=200
# Gen260: best=9:33:06 survivors=200
# Gen261: best=9:33:06 survivors=200
# Gen262: best=9:33:06 survivors=200
# Gen263: best=9:33:06 survivors=200
# Gen264: best=9:33:06 survivors=200
# Gen265: best=9:33:06 survivors=200
# Gen266: best=9:33:06 survivors=200
# Gen267: best=9:33:06 survivors=200
# Gen268: best=9:33:06 survivors=200
# Gen269: best=9:33:06 survivors=200
# Gen270: best=9:33:06 survivors=200
# Gen271: best=9:33:06 survivors=200
# Gen272: best=9:33:06 survivors=200
# Gen273: best=9:33:06 survivors=200
# Gen274: best=9:33:06 survivors=200
# Gen275: best=9:33:06 survivors=200
# Gen276: best=9:33:06 survivors=200
# Gen277: best=9:33:06 survivors=200
# Gen278: best=9:33:06 survivors=200
# Gen279: best=9:33:06 survivors=200
# Gen280: best=9:33:06 survivors=200
# Gen281: best=9:33:06 survivors=200
# Gen282: best=9:33:06 survivors=200
# Gen283: best=9:33:06 survivors=200
# Gen284: best=9:33:06 survivors=200
# Gen285: best=9:33:06 survivors=200
# Gen286: best=9:33:06 survivors=200
# Gen287: best=9:33:06 survivors=200
# Gen288: best=9:33:06 survivors=200
# Gen289: best=9:33:06 survivors=200
# Gen290: best=9:33:06 survivors=200
# Gen291: best=9:33:06 survivors=200
# Gen292: best=9:33:06 survivors=200
# Gen293: best=9:33:06 survivors=200
# Gen294: best=9:24:00 survivors=200
# Gen295: best=9:24:00 survivors=200
# Gen296: best=9:24:00 survivors=200
# Gen297: best=9:24:00 survivors=200
# Gen298: best=9:24:00 survivors=200
# Gen299: best=9:24:00 survivors=200
# Gen300: best=9:24:00 survivors=200
# Gen301: best=9:24:00 survivors=200
# Gen302: best=9:24:00 survivors=200
# Gen303: best=9:24:00 survivors=200
# Gen304: best=9:24:00 survivors=200
# Gen305: best=9:24:00 survivors=200
# Gen306: best=9:24:00 survivors=200
# Gen307: best=9:24:00 survivors=200
# Gen308: best=9:24:00 survivors=200
# Gen309: best=9:24:00 survivors=200
# Gen310: best=9:24:00 survivors=200
# Gen311: best=9:24:00 survivors=200
# Gen312: best=9:24:00 survivors=200
# Gen313: best=9:24:00 survivors=200
# Gen314: best=9:24:00 survivors=200
# Gen315: best=9:24:00 survivors=200
# Gen316: best=9:24:00 survivors=200
# Gen317: best=9:24:00 survivors=200
# Gen318: best=9:24:00 survivors=200
# Gen319: best=9:24:00 survivors=200
# Gen320: best=9:24:00 survivors=200
# Gen321: best=9:24:00 survivors=200
# Gen322: best=9:24:00 survivors=200
# Gen323: best=9:24:00 survivors=200
# Gen324: best=9:24:00 survivors=200
# Gen325: best=9:24:00 survivors=200
# Gen326: best=9:24:00 survivors=200
# Gen327: best=9:24:00 survivors=200
# Gen328: best=9:24:00 survivors=200
# Gen329: best=9:24:00 survivors=200
# Gen330: best=9:24:00 survivors=200
# Gen331: best=9:24:00 survivors=200
# Gen332: best=9:24:00 survivors=200
# Gen333: best=9:24:00 survivors=200
# Gen334: best=9:24:00 survivors=200
# Gen335: best=9:24:00 survivors=200
# Gen336: best=9:24:00 survivors=200
# Gen337: best=9:24:00 survivors=200
# Gen338: best=9:24:00 survivors=200
# Gen339: best=9:24:00 survivors=200
# Gen340: best=9:24:00 survivors=200
# Gen341: best=9:24:00 survivors=200
# Gen342: best=9:24:00 survivors=200
# Gen343: best=9:24:00 survivors=200
# Gen344: best=9:24:00 survivors=200
# Gen345: best=9:24:00 survivors=200
# Gen346: best=9:24:00 survivors=200
# Gen347: best=9:24:00 survivors=200
# Gen348: best=9:24:00 survivors=200
# Gen349: best=9:24:00 survivors=200
# Gen350: best=9:24:00 survivors=200
# Gen351: best=9:24:00 survivors=200
# Gen352: best=9:24:00 survivors=200
# Gen353: best=9:24:00 survivors=200
# Gen354: best=9:24:00 survivors=200
# Gen355: best=9:24:00 survivors=200
# Gen356: best=9:24:00 survivors=200
# Gen357: best=9:24:00 survivors=200
# Gen358: best=9:24:00 survivors=200
# Gen359: best=9:24:00 survivors=200
# Gen360: best=9:24:00 survivors=200
# Gen361: best=9:24:00 survivors=200
# Gen362: best=9:24:00 survivors=200
# Gen363: best=9:24:00 survivors=200
# Gen364: best=9:24:00 survivors=200
# Gen365: best=9:24:00 survivors=200
# Gen366: best=9:24:00 survivors=200
# Gen367: best=9:24:00 survivors=200
# Gen368: best=9:24:00 survivors=200
# Gen369: best=9:24:00 survivors=200
# Gen370: best=9:24:00 survivors=200
# Gen371: best=9:24:00 survivors=200
# Gen372: best=9:24:00 survivors=200
# Gen373: best=9:24:00 survivors=200
# Gen374: best=9:24:00 survivors=200
# Gen375: best=9:24:00 survivors=200
# Gen376: best=9:24:00 survivors=200
# Gen377: best=9:24:00 survivors=200
# Gen378: best=9:24:00 survivors=200
# Gen379: best=9:24:00 survivors=200
# Gen380: best=9:24:00 survivors=200
# Gen381: best=9:24:00 survivors=200
# Gen382: best=9:24:00 survivors=200
# Gen383: best=9:24:00 survivors=200
# Gen384: best=9:24:00 survivors=200
# Gen385: best=9:24:00 survivors=200
# Gen386: best=9:24:00 survivors=200
# Gen387: best=9:24:00 survivors=200
# Gen388: best=9:24:00 survivors=200
# Gen389: best=9:24:00 survivors=200
# Gen390: best=9:24:00 survivors=200
# Gen391: best=9:24:00 survivors=200
# Gen392: best=9:24:00 survivors=200
# Gen393: best=9:24:00 survivors=200
# Gen394: best=9:24:00 survivors=200
# Gen395: best=9:24:00 survivors=200
# Gen396: best=9:24:00 survivors=200
# Gen397: best=9:24:00 survivors=200
# Gen398: best=9:24:00 survivors=200
# Gen399: best=9:24:00 survivors=200
# Gen400: best=9:24:00 survivors=200
# Gen401: best=9:24:00 survivors=200
# Gen402: best=9:24:00 survivors=200
# Gen403: best=9:24:00 survivors=200
# Gen404: best=9:24:00 survivors=200
# Gen405: best=9:24:00 survivors=200
# Gen406: best=9:24:00 survivors=200
# Gen407: best=9:24:00 survivors=200
# Gen408: best=9:24:00 survivors=200
# Gen409: best=9:24:00 survivors=200
# Gen410: best=9:24:00 survivors=200
# Gen411: best=9:24:00 survivors=200
# Gen412: best=9:24:00 survivors=200
# Gen413: best=9:24:00 survivors=200
# Gen414: best=9:24:00 survivors=200
# Gen415: best=9:24:00 survivors=200
# Gen416: best=9:24:00 survivors=200
# Gen417: best=9:24:00 survivors=200
# Gen418: best=9:24:00 survivors=200
# Gen419: best=9:24:00 survivors=200
# Gen420: best=9:24:00 survivors=200
# Gen421: best=9:24:00 survivors=200
# Gen422: best=9:24:00 survivors=200
# Gen423: best=9:24:00 survivors=200
# Gen424: best=9:24:00 survivors=200
# Gen425: best=9:24:00 survivors=200
# Gen426: best=9:24:00 survivors=200
# Gen427: best=9:24:00 survivors=200
# Gen428: best=9:24:00 survivors=200
# Gen429: best=9:24:00 survivors=200
# Gen430: best=9:24:00 survivors=200
# Gen431: best=9:24:00 survivors=200
# Gen432: best=9:24:00 survivors=200
# Gen433: best=9:24:00 survivors=200
# Gen434: best=9:24:00 survivors=200
# Gen435: best=9:24:00 survivors=200
# Gen436: best=9:24:00 survivors=200
# Gen437: best=9:24:00 survivors=200
# Gen438: best=9:24:00 survivors=200
# Gen439: best=9:24:00 survivors=200
# Gen440: best=9:24:00 survivors=200
# Gen441: best=9:24:00 survivors=200
# Gen442: best=9:24:00 survivors=200
# Gen443: best=9:24:00 survivors=200
# Gen444: best=9:24:00 survivors=200
# Gen445: best=9:24:00 survivors=200
# Gen446: best=9:24:00 survivors=200
# Gen447: best=9:24:00 survivors=200
# Gen448: best=9:24:00 survivors=200
# Gen449: best=9:24:00 survivors=200
# Gen450: best=9:24:00 survivors=200
# Gen451: best=9:24:00 survivors=200
# Gen452: best=9:24:00 survivors=200
# Gen453: best=9:24:00 survivors=200
# Gen454: best=9:24:00 survivors=200
# Gen455: best=9:24:00 survivors=200
# Gen456: best=9:24:00 survivors=200
# Gen457: best=9:24:00 survivors=200
# Gen458: best=9:24:00 survivors=200
# Gen459: best=9:24:00 survivors=200
# Gen460: best=9:24:00 survivors=200
# Gen461: best=9:24:00 survivors=200
# Gen462: best=9:24:00 survivors=200
# Gen463: best=9:24:00 survivors=200
# Gen464: best=9:24:00 survivors=200
# Gen465: best=9:24:00 survivors=200
# Gen466: best=9:24:00 survivors=200
# Gen467: best=9:24:00 survivors=200
# Gen468: best=9:24:00 survivors=200
# Gen469: best=9:24:00 survivors=200
# Gen470: best=9:24:00 survivors=200
# Gen471: best=9:24:00 survivors=200
# Gen472: best=9:24:00 survivors=200
# Gen473: best=9:24:00 survivors=200
# Gen474: best=9:24:00 survivors=200
# Gen475: best=9:24:00 survivors=200
# Gen476: best=9:24:00 survivors=200
# Gen477: best=9:24:00 survivors=200
# Gen478: best=9:24:00 survivors=200
# Gen479: best=9:24:00 survivors=200
# Gen480: best=9:24:00 survivors=200
# Gen481: best=9:24:00 survivors=200
# Gen482: best=9:24:00 survivors=200
# Gen483: best=9:24:00 survivors=200
# Gen484: best=9:24:00 survivors=200
# Gen485: best=9:24:00 survivors=200
# Gen486: best=9:24:00 survivors=200
# Gen487: best=9:24:00 survivors=200
# Gen488: best=9:24:00 survivors=200
# Gen489: best=9:24:00 survivors=200
# Gen490: best=9:24:00 survivors=200
# Gen491: best=9:24:00 survivors=200
# Gen492: best=9:24:00 survivors=200
# Gen493: best=9:24:00 survivors=200
# Gen494: best=9:24:00 survivors=200
# Gen495: best=9:24:00 survivors=200
# Gen496: best=9:24:00 survivors=200
# Gen497: best=9:24:00 survivors=200
# Gen498: best=9:24:00 survivors=200
# Gen499: best=9:24:00 survivors=200
# Gen500: best=9:24:00 survivors=200
# Gen501: best=9:24:00 survivors=200
# Gen502: best=9:24:00 survivors=200
# Gen503: best=9:24:00 survivors=200
# Gen504: best=9:24:00 survivors=200
# Gen505: best=9:24:00 survivors=200
# Gen506: best=9:24:00 survivors=200
# Gen507: best=9:24:00 survivors=200
# Gen508: best=9:24:00 survivors=200
# Gen509: best=9:24:00 survivors=200
# Gen510: best=9:24:00 survivors=200
# Gen511: best=9:24:00 survivors=200
# Gen512: best=9:24:00 survivors=200
# Gen513: best=9:24:00 survivors=200
# Gen514: best=9:24:00 survivors=200
# Gen515: best=9:24:00 survivors=200
# Gen516: best=9:24:00 survivors=200
# Gen517: best=9:24:00 survivors=200
# Gen518: best=9:24:00 survivors=200
# Gen519: best=9:24:00 survivors=200
# Gen520: best=9:24:00 survivors=200
# Gen521: best=9:24:00 survivors=200
# Gen522: best=9:24:00 survivors=200
# Gen523: best=9:24:00 survivors=200
# Gen524: best=9:24:00 survivors=200
# Gen525: best=9:24:00 survivors=200
# Gen526: best=9:24:00 survivors=200
# Gen527: best=9:24:00 survivors=200
# Gen528: best=9:24:00 survivors=200
# Gen529: best=9:24:00 survivors=200
# Gen530: best=9:24:00 survivors=200
# Gen531: best=9:24:00 survivors=200
# Gen532: best=9:24:00 survivors=200
# Gen533: best=9:24:00 survivors=200
# Gen534: best=9:24:00 survivors=200
# Gen535: best=9:24:00 survivors=200
# Gen536: best=9:24:00 survivors=200
# Gen537: best=9:24:00 survivors=200
# Gen538: best=9:24:00 survivors=200
# Gen539: best=9:24:00 survivors=200
# Gen540: best=9:24:00 survivors=200
# Gen541: best=9:24:00 survivors=200
# Gen542: best=9:24:00 survivors=200
# Gen543: best=9:24:00 survivors=200
# Gen544: best=9:24:00 survivors=200
# Gen545: best=9:24:00 survivors=200
# Gen546: best=9:24:00 survivors=200
# Gen547: best=9:24:00 survivors=200
# Gen548: best=9:24:00 survivors=200
# Gen549: best=9:24:00 survivors=200
# Gen550: best=9:24:00 survivors=200
# Gen551: best=9:24:00 survivors=200
# Gen552: best=9:24:00 survivors=200
# Gen553: best=9:24:00 survivors=200
# Gen554: best=9:24:00 survivors=200
# Gen555: best=9:24:00 survivors=200
# Gen556: best=9:24:00 survivors=200
# Gen557: best=9:24:00 survivors=200
# Gen558: best=9:24:00 survivors=200
# Gen559: best=9:24:00 survivors=200
# Gen560: best=9:24:00 survivors=200
# Gen561: best=9:24:00 survivors=200
# Gen562: best=9:24:00 survivors=200
# Gen563: best=9:24:00 survivors=200
# Gen564: best=9:24:00 survivors=200
# Gen565: best=9:24:00 survivors=200
# Gen566: best=9:24:00 survivors=200
# Gen567: best=9:24:00 survivors=200
# Gen568: best=9:24:00 survivors=200
# Gen569: best=9:24:00 survivors=200
# Gen570: best=9:24:00 survivors=200
# Gen571: best=9:24:00 survivors=200
# Gen572: best=9:24:00 survivors=200
# Gen573: best=9:24:00 survivors=200
# Gen574: best=9:24:00 survivors=200
# Gen575: best=9:24:00 survivors=200
# Gen576: best=9:24:00 survivors=200
# Gen577: best=9:24:00 survivors=200
# Gen578: best=9:24:00 survivors=200
# Gen579: best=9:24:00 survivors=200
# Gen580: best=9:24:00 survivors=200
# Gen581: best=9:24:00 survivors=200
# Gen582: best=9:24:00 survivors=200
# Gen583: best=9:24:00 survivors=200
# Gen584: best=9:24:00 survivors=200
# Gen585: best=9:24:00 survivors=200
# Gen586: best=9:24:00 survivors=200
# Gen587: best=9:24:00 survivors=200
# Gen588: best=9:24:00 survivors=200
# Gen589: best=9:24:00 survivors=200
# Gen590: best=9:24:00 survivors=200
# Gen591: best=9:24:00 survivors=200
# Gen592: best=9:24:00 survivors=200
# Gen593: best=9:24:00 survivors=200
# Gen594: best=9:24:00 survivors=200
# Gen595: best=9:24:00 survivors=200
# Gen596: best=9:24:00 survivors=200
# Gen597: best=9:24:00 survivors=200
# Gen598: best=9:24:00 survivors=200
# Gen599: best=9:24:00 survivors=200
# Gen600: best=9:24:00 survivors=200
# Gen601: best=9:24:00 survivors=200
# Gen602: best=9:24:00 survivors=200
# Gen603: best=9:24:00 survivors=200
# Gen604: best=9:24:00 survivors=200
# Gen605: best=9:24:00 survivors=200
# Gen606: best=9:24:00 survivors=200
# Gen607: best=9:24:00 survivors=200
# Gen608: best=9:24:00 survivors=200
# Gen609: best=9:24:00 survivors=200
# Gen610: best=9:24:00 survivors=200
# Gen611: best=9:24:00 survivors=200
# Gen612: best=9:24:00 survivors=200
# Gen613: best=9:24:00 survivors=200
# Gen614: best=9:24:00 survivors=200
# Gen615: best=9:24:00 survivors=200
# Gen616: best=9:24:00 survivors=200
# Gen617: best=9:24:00 survivors=200
# Gen618: best=9:24:00 survivors=200
# Gen619: best=9:24:00 survivors=200
# Gen620: best=9:24:00 survivors=200
# Gen621: best=9:24:00 survivors=200
# Gen622: best=9:24:00 survivors=200
# Gen623: best=9:24:00 survivors=200
# Gen624: best=9:24:00 survivors=200
# Gen625: best=9:24:00 survivors=200
# Gen626: best=9:24:00 survivors=200
# Gen627: best=9:24:00 survivors=200
# Gen628: best=9:24:00 survivors=200
# Gen629: best=9:24:00 survivors=200
# Gen630: best=9:24:00 survivors=200
# Gen631: best=9:24:00 survivors=200
# Gen632: best=9:24:00 survivors=200
# Gen633: best=9:24:00 survivors=200
# Gen634: best=9:24:00 survivors=200
# Gen635: best=9:24:00 survivors=200
# Gen636: best=9:24:00 survivors=200
# Gen637: best=9:24:00 survivors=200
# Gen638: best=9:24:00 survivors=200
# Gen639: best=9:24:00 survivors=200
# Gen640: best=9:24:00 survivors=200
# Gen641: best=9:24:00 survivors=200
# Gen642: best=9:24:00 survivors=200
# Gen643: best=9:24:00 survivors=200
# Gen644: best=9:24:00 survivors=200
# Gen645: best=9:24:00 survivors=200
# Gen646: best=9:24:00 survivors=200
# Gen647: best=9:24:00 survivors=200
# Gen648: best=9:24:00 survivors=200
# Gen649: best=9:24:00 survivors=200
# Gen650: best=9:24:00 survivors=200
# Gen651: best=9:24:00 survivors=200
# Gen652: best=9:24:00 survivors=200
# Gen653: best=9:24:00 survivors=200
# Gen654: best=9:24:00 survivors=200
# Gen655: best=9:24:00 survivors=200
# Gen656: best=9:24:00 survivors=200
# Gen657: best=9:24:00 survivors=200
# Gen658: best=9:24:00 survivors=200
# Gen659: best=9:24:00 survivors=200
# Gen660: best=9:24:00 survivors=200
# Gen661: best=9:24:00 survivors=200
# Gen662: best=9:24:00 survivors=200
# Gen663: best=9:24:00 survivors=200
# Gen664: best=9:24:00 survivors=200
# Gen665: best=9:24:00 survivors=200
# Gen666: best=9:24:00 survivors=200
# Gen667: best=9:24:00 survivors=200
# Gen668: best=9:24:00 survivors=200
# Gen669: best=9:24:00 survivors=200
# Gen670: best=9:24:00 survivors=200
# Gen671: best=9:24:00 survivors=200
# Gen672: best=9:24:00 survivors=200
# Gen673: best=9:24:00 survivors=200
# Gen674: best=9:24:00 survivors=200
# Gen675: best=9:24:00 survivors=200
# Gen676: best=9:24:00 survivors=200
# Gen677: best=9:24:00 survivors=200
# Gen678: best=9:24:00 survivors=200
# Gen679: best=9:24:00 survivors=200
# Gen680: best=9:24:00 survivors=200
# Gen681: best=9:24:00 survivors=200
# Gen682: best=9:24:00 survivors=200
# Gen683: best=9:24:00 survivors=200
# Gen684: best=9:24:00 survivors=200
# Gen685: best=9:24:00 survivors=200
# Gen686: best=9:24:00 survivors=200
# Gen687: best=9:24:00 survivors=200
# Gen688: best=9:24:00 survivors=200
# Gen689: best=9:24:00 survivors=200
# Gen690: best=9:24:00 survivors=200
# Gen691: best=9:24:00 survivors=200
# Gen692: best=9:24:00 survivors=200
# Gen693: best=9:24:00 survivors=200
# Gen694: best=9:24:00 survivors=200
# Gen695: best=9:24:00 survivors=200
# Gen696: best=9:24:00 survivors=200
# Gen697: best=9:24:00 survivors=200
# Gen698: best=9:24:00 survivors=200
# Gen699: best=9:24:00 survivors=200
# Gen700: best=9:24:00 survivors=200
# Gen701: best=9:24:00 survivors=200
# Gen702: best=9:24:00 survivors=200
# Gen703: best=9:24:00 survivors=200
# Gen704: best=9:24:00 survivors=200
# Gen705: best=9:24:00 survivors=200
# Gen706: best=9:24:00 survivors=200
# Gen707: best=9:24:00 survivors=200
# Gen708: best=9:24:00 survivors=200
# Gen709: best=9:24:00 survivors=200
# Gen710: best=9:24:00 survivors=200
# Gen711: best=9:24:00 survivors=200
# Gen712: best=9:24:00 survivors=200
# Gen713: best=9:24:00 survivors=200
# Gen714: best=9:24:00 survivors=200
# Gen715: best=9:24:00 survivors=200
# Gen716: best=9:24:00 survivors=200
# Gen717: best=9:24:00 survivors=200
# Gen718: best=9:24:00 survivors=200
# Gen719: best=9:24:00 survivors=200
# Gen720: best=9:24:00 survivors=200
# Gen721: best=9:24:00 survivors=200
# Gen722: best=9:24:00 survivors=200
# Gen723: best=9:24:00 survivors=200
# Gen724: best=9:24:00 survivors=200
# Gen725: best=9:24:00 survivors=200
# Gen726: best=9:24:00 survivors=200
# Gen727: best=9:24:00 survivors=200
# Gen728: best=9:24:00 survivors=200
# Gen729: best=9:24:00 survivors=200
# Gen730: best=9:24:00 survivors=200
# Gen731: best=9:24:00 survivors=200
# Gen732: best=9:24:00 survivors=200
# Gen733: best=9:24:00 survivors=200
# Gen734: best=9:24:00 survivors=200
# Gen735: best=9:24:00 survivors=200
# Gen736: best=9:24:00 survivors=200
# Gen737: best=9:24:00 survivors=200
# Gen738: best=9:24:00 survivors=200
# Gen739: best=9:24:00 survivors=200
# Gen740: best=9:24:00 survivors=200
# Gen741: best=9:24:00 survivors=200
# Gen742: best=9:24:00 survivors=200
# Gen743: best=9:24:00 survivors=200
# Gen744: best=9:24:00 survivors=200
# Gen745: best=9:24:00 survivors=200
# Gen746: best=9:24:00 survivors=200
# Gen747: best=9:24:00 survivors=200
# Gen748: best=9:24:00 survivors=200
# Gen749: best=9:24:00 survivors=200
# Gen750: best=9:24:00 survivors=200
# Gen751: best=9:24:00 survivors=200
# Gen752: best=9:24:00 survivors=200
# Gen753: best=9:24:00 survivors=200
# Gen754: best=9:24:00 survivors=200
# Gen755: best=9:24:00 survivors=200
# Gen756: best=9:24:00 survivors=200
# Gen757: best=9:24:00 survivors=200
# Gen758: best=9:24:00 survivors=200
# Gen759: best=9:24:00 survivors=200
# Gen760: best=9:24:00 survivors=200
# Gen761: best=9:24:00 survivors=200
# Gen762: best=9:24:00 survivors=200
# Gen763: best=9:24:00 survivors=200
# Gen764: best=9:24:00 survivors=200
# Gen765: best=9:24:00 survivors=200
# Gen766: best=9:24:00 survivors=200
# Gen767: best=9:24:00 survivors=200
# Gen768: best=9:24:00 survivors=200
# Gen769: best=9:24:00 survivors=200
# Gen770: best=9:24:00 survivors=200
# Gen771: best=9:24:00 survivors=200
# Gen772: best=9:24:00 survivors=200
# Gen773: best=9:24:00 survivors=200
# Gen774: best=9:24:00 survivors=200
# Gen775: best=9:24:00 survivors=200
# Gen776: best=9:24:00 survivors=200
# Gen777: best=9:24:00 survivors=200
# Gen778: best=9:24:00 survivors=200
# Gen779: best=9:24:00 survivors=200
# Gen780: best=9:24:00 survivors=200
# Gen781: best=9:24:00 survivors=200
# Gen782: best=9:24:00 survivors=200
# Gen783: best=9:24:00 survivors=200
# Gen784: best=9:24:00 survivors=200
# Gen785: best=9:24:00 survivors=200
# Gen786: best=9:24:00 survivors=200
# Gen787: best=9:24:00 survivors=200
# Gen788: best=9:24:00 survivors=200
# Gen789: best=9:24:00 survivors=200
# Gen790: best=9:24:00 survivors=200
# Gen791: best=9:24:00 survivors=200
# Gen792: best=9:24:00 survivors=200
# Gen793: best=9:24:00 survivors=200
# Gen794: best=9:24:00 survivors=200
# Gen795: best=9:24:00 survivors=200
# Gen796: best=9:24:00 survivors=200
# Gen797: best=9:24:00 survivors=200
# Gen798: best=9:24:00 survivors=200
# Gen799: best=9:24:00 survivors=200
# Gen800: best=9:24:00 survivors=200
# Gen801: best=9:24:00 survivors=200
# Gen802: best=9:24:00 survivors=200
# Gen803: best=9:24:00 survivors=200
# Gen804: best=9:24:00 survivors=200
# Gen805: best=9:24:00 survivors=200
# Gen806: best=9:24:00 survivors=200
# Gen807: best=9:24:00 survivors=200
# Gen808: best=9:24:00 survivors=200
# Gen809: best=9:24:00 survivors=200
# Gen810: best=9:24:00 survivors=200
# Gen811: best=9:24:00 survivors=200
# Gen812: best=9:24:00 survivors=200
# Gen813: best=9:24:00 survivors=200
# Gen814: best=9:24:00 survivors=200
# Gen815: best=9:24:00 survivors=200
# Gen816: best=9:24:00 survivors=200
# Gen817: best=9:24:00 survivors=200
# Gen818: best=9:24:00 survivors=200
# Gen819: best=9:24:00 survivors=200
# Gen820: best=9:24:00 survivors=200
# Gen821: best=9:24:00 survivors=200
# Gen822: best=9:24:00 survivors=200
# Gen823: best=9:24:00 survivors=200
# Gen824: best=9:24:00 survivors=200
# Gen825: best=9:24:00 survivors=200
# Gen826: best=9:24:00 survivors=200
# Gen827: best=9:24:00 survivors=200
# Gen828: best=9:24:00 survivors=200
# Gen829: best=9:24:00 survivors=200
# Gen830: best=9:24:00 survivors=200
# Gen831: best=9:24:00 survivors=200
# Gen832: best=9:24:00 survivors=200
# Gen833: best=9:24:00 survivors=200
# Gen834: best=9:24:00 survivors=200
# Gen835: best=9:24:00 survivors=200
# Gen836: best=9:24:00 survivors=200
# Gen837: best=9:24:00 survivors=200
# Gen838: best=9:24:00 survivors=200
# Gen839: best=9:24:00 survivors=200
# Gen840: best=9:24:00 survivors=200
# Gen841: best=9:24:00 survivors=200
# Gen842: best=9:24:00 survivors=200
# Gen843: best=9:24:00 survivors=200
# Gen844: best=9:24:00 survivors=200
# Gen845: best=9:24:00 survivors=200
# Gen846: best=9:24:00 survivors=200
# Gen847: best=9:24:00 survivors=200
# Gen848: best=9:24:00 survivors=200
# Gen849: best=9:24:00 survivors=200
# Gen850: best=9:24:00 survivors=200
# Gen851: best=9:24:00 survivors=200
# Gen852: best=9:24:00 survivors=200
# Gen853: best=9:24:00 survivors=200
# Gen854: best=9:24:00 survivors=200
# Gen855: best=9:24:00 survivors=200
# Gen856: best=9:24:00 survivors=200
# Gen857: best=9:24:00 survivors=200
# Gen858: best=9:24:00 survivors=200
# Gen859: best=9:24:00 survivors=200
# Gen860: best=9:24:00 survivors=200
# Gen861: best=9:24:00 survivors=200
# Gen862: best=9:24:00 survivors=200
# Gen863: best=9:24:00 survivors=200
# Gen864: best=9:24:00 survivors=200
# Gen865: best=9:24:00 survivors=200
# Gen866: best=9:24:00 survivors=200
# Gen867: best=9:24:00 survivors=200
# Gen868: best=9:24:00 survivors=200
# Gen869: best=9:24:00 survivors=200
# Gen870: best=9:24:00 survivors=200
# Gen871: best=9:24:00 survivors=200
# Gen872: best=9:24:00 survivors=200
# Gen873: best=9:24:00 survivors=200
# Gen874: best=9:24:00 survivors=200
# Gen875: best=9:24:00 survivors=200
# Gen876: best=9:24:00 survivors=200
# Gen877: best=9:24:00 survivors=200
# Gen878: best=9:24:00 survivors=200
# Gen879: best=9:24:00 survivors=200
# Gen880: best=9:24:00 survivors=200
# Gen881: best=9:24:00 survivors=200
# Gen882: best=9:24:00 survivors=200
# Gen883: best=9:24:00 survivors=200
# Gen884: best=9:24:00 survivors=200
# Gen885: best=9:24:00 survivors=200
# Gen886: best=9:24:00 survivors=200
# Gen887: best=9:24:00 survivors=200
# Gen888: best=9:24:00 survivors=200
# Gen889: best=9:24:00 survivors=200
# Gen890: best=9:24:00 survivors=200
# Gen891: best=9:24:00 survivors=200
# Gen892: best=9:24:00 survivors=200
# Gen893: best=9:24:00 survivors=200
# Gen894: best=9:24:00 survivors=200
# Gen895: best=9:24:00 survivors=200
# Gen896: best=9:24:00 survivors=200
# Gen897: best=9:24:00 survivors=200
# Gen898: best=9:24:00 survivors=200
# Gen899: best=9:24:00 survivors=200
# Gen900: best=9:24:00 survivors=200
# Gen901: best=9:24:00 survivors=200
# Gen902: best=9:24:00 survivors=200
# Gen903: best=9:24:00 survivors=200
# Gen904: best=9:24:00 survivors=200
# Gen905: best=9:24:00 survivors=200
# Gen906: best=9:24:00 survivors=200
# Gen907: best=9:24:00 survivors=200
# Gen908: best=9:24:00 survivors=200
# Gen909: best=9:24:00 survivors=200
# Gen910: best=9:24:00 survivors=200
# Gen911: best=9:24:00 survivors=200
# Gen912: best=9:24:00 survivors=200
# Gen913: best=9:24:00 survivors=200
# Gen914: best=9:24:00 survivors=200
# Gen915: best=9:24:00 survivors=200
# Gen916: best=9:24:00 survivors=200
# Gen917: best=9:24:00 survivors=200
# Gen918: best=9:24:00 survivors=200
# Gen919: best=9:24:00 survivors=200
# Gen920: best=9:24:00 survivors=200
# Gen921: best=9:24:00 survivors=200
# Gen922: best=9:24:00 survivors=200
# Gen923: best=9:24:00 survivors=200
# Gen924: best=9:24:00 survivors=200
# Gen925: best=9:24:00 survivors=200
# Gen926: best=9:24:00 survivors=200
# Gen927: best=9:24:00 survivors=200
# Gen928: best=9:24:00 survivors=200
# Gen929: best=9:24:00 survivors=200
# Gen930: best=9:24:00 survivors=200
# Gen931: best=9:24:00 survivors=200
# Gen932: best=9:24:00 survivors=200
# Gen933: best=9:24:00 survivors=200
# Gen934: best=9:24:00 survivors=200
# Gen935: best=9:24:00 survivors=200
# Gen936: best=9:24:00 survivors=200
# Gen937: best=9:24:00 survivors=200
# Gen938: best=9:24:00 survivors=200
# Gen939: best=9:24:00 survivors=200
# Gen940: best=9:24:00 survivors=200
# Gen941: best=9:24:00 survivors=200
# Gen942: best=9:24:00 survivors=200
# Gen943: best=9:24:00 survivors=200
# Gen944: best=9:24:00 survivors=200
# Gen945: best=9:24:00 survivors=200
# Gen946: best=9:24:00 survivors=200
# Gen947: best=9:24:00 survivors=200
# Gen948: best=9:24:00 survivors=200
# Gen949: best=9:24:00 survivors=200
# Gen950: best=9:24:00 survivors=200
# Gen951: best=9:24:00 survivors=200
# Gen952: best=9:24:00 survivors=200
# Gen953: best=9:24:00 survivors=200
# Gen954: best=9:24:00 survivors=200
# Gen955: best=9:24:00 survivors=200
# Gen956: best=9:24:00 survivors=200
# Gen957: best=9:24:00 survivors=200
# Gen958: best=9:24:00 survivors=200
# Gen959: best=9:24:00 survivors=200
# Gen960: best=9:24:00 survivors=200
# Gen961: best=9:24:00 survivors=200
# Gen962: best=9:24:00 survivors=200
# Gen963: best=9:24:00 survivors=200
# Gen964: best=9:24:00 survivors=200
# Gen965: best=9:24:00 survivors=200
# Gen966: best=9:24:00 survivors=200
# Gen967: best=9:24:00 survivors=200
# Gen968: best=9:24:00 survivors=200
# Gen969: best=9:24:00 survivors=200
# Gen970: best=9:24:00 survivors=200
# Gen971: best=9:24:00 survivors=200
# Gen972: best=9:24:00 survivors=200
# Gen973: best=9:24:00 survivors=200
# Gen974: best=9:24:00 survivors=200
# Gen975: best=9:24:00 survivors=200
# Gen976: best=9:24:00 survivors=200
# Gen977: best=9:24:00 survivors=200
# Gen978: best=9:24:00 survivors=200
# Gen979: best=9:24:00 survivors=200
# Gen980: best=9:24:00 survivors=200
# Gen981: best=9:24:00 survivors=200
# Gen982: best=9:24:00 survivors=200
# Gen983: best=9:24:00 survivors=200
# Gen984: best=9:24:00 survivors=200
# Gen985: best=9:24:00 survivors=200
# Gen986: best=9:24:00 survivors=200
# Gen987: best=9:24:00 survivors=200
# Gen988: best=9:24:00 survivors=200
# Gen989: best=9:24:00 survivors=200
# Gen990: best=9:24:00 survivors=200
# Gen991: best=9:24:00 survivors=200
# Gen992: best=9:24:00 survivors=200
# Gen993: best=9:24:00 survivors=200
# Gen994: best=9:24:00 survivors=200
# Gen995: best=9:24:00 survivors=200
# Gen996: best=9:24:00 survivors=200
# Gen997: best=9:24:00 survivors=200
# Gen998: best=9:24:00 survivors=200
# Gen999: best=9:24:00 survivors=200
# Gen1000: best=9:24:00 survivors=200
# Gen1001: best=9:24:00 survivors=200
# Gen1002: best=9:24:00 survivors=200
# Gen1003: best=9:24:00 survivors=200
# Gen1004: best=9:24:00 survivors=200
# Gen1005: best=9:24:00 survivors=200
# Gen1006: best=9:24:00 survivors=200
# Gen1007: best=9:24:00 survivors=200
# Gen1008: best=9:24:00 survivors=200
# Gen1009: best=9:24:00 survivors=200
# Gen1010: best=9:24:00 survivors=200
# Gen1011: best=9:24:00 survivors=200
# Gen1012: best=9:24:00 survivors=200
# Gen1013: best=9:24:00 survivors=200
# Gen1014: best=9:24:00 survivors=200
# Gen1015: best=9:24:00 survivors=200
# Gen1016: best=9:24:00 survivors=200
# Gen1017: best=9:24:00 survivors=200
# Gen1018: best=9:24:00 survivors=200
# Gen1019: best=9:24:00 survivors=200
# Gen1020: best=9:24:00 survivors=200
# Gen1021: best=9:24:00 survivors=200
# Gen1022: best=9:24:00 survivors=200
# Gen1023: best=9:24:00 survivors=200
# Gen1024: best=9:24:00 survivors=200
# Gen1025: best=9:24:00 survivors=200
# Gen1026: best=9:24:00 survivors=200
# Gen1027: best=9:24:00 survivors=200
# Gen1028: best=9:24:00 survivors=200
# Gen1029: best=9:24:00 survivors=200
# Gen1030: best=9:24:00 survivors=200
# Gen1031: best=9:24:00 survivors=200
# Gen1032: best=9:24:00 survivors=200
# Gen1033: best=9:24:00 survivors=200
# Gen1034: best=9:24:00 survivors=200
# Gen1035: best=9:24:00 survivors=200
# Gen1036: best=9:24:00 survivors=200
# Gen1037: best=9:24:00 survivors=200
# Gen1038: best=9:24:00 survivors=200
# Gen1039: best=9:24:00 survivors=200
# Gen1040: best=9:24:00 survivors=200
# Gen1041: best=9:24:00 survivors=200
# Gen1042: best=9:24:00 survivors=200
# Gen1043: best=9:24:00 survivors=200
# Gen1044: best=9:24:00 survivors=200
# Gen1045: best=9:24:00 survivors=200
# Gen1046: best=9:24:00 survivors=200
# Gen1047: best=9:24:00 survivors=200
# Gen1048: best=9:24:00 survivors=200
# Gen1049: best=9:24:00 survivors=200
# Gen1050: best=9:24:00 survivors=200
# Gen1051: best=9:24:00 survivors=200
# Gen1052: best=9:24:00 survivors=200
# Gen1053: best=9:24:00 survivors=200
# Gen1054: best=9:24:00 survivors=200
# Gen1055: best=9:24:00 survivors=200
# Gen1056: best=9:24:00 survivors=200
# Gen1057: best=9:24:00 survivors=200
# Gen1058: best=9:24:00 survivors=200
# Gen1059: best=9:24:00 survivors=200
# Gen1060: best=9:24:00 survivors=200
# Gen1061: best=9:24:00 survivors=200
# Gen1062: best=9:24:00 survivors=200
# Gen1063: best=9:24:00 survivors=200
# Gen1064: best=9:24:00 survivors=200
# Gen1065: best=9:24:00 survivors=200
# Gen1066: best=9:24:00 survivors=200
# Gen1067: best=9:24:00 survivors=200
# Gen1068: best=9:24:00 survivors=200
# Gen1069: best=9:24:00 survivors=200
# Gen1070: best=9:24:00 survivors=200
# Gen1071: best=9:24:00 survivors=200
# Gen1072: best=9:24:00 survivors=200
# Gen1073: best=9:24:00 survivors=200
# Gen1074: best=9:24:00 survivors=200
# Gen1075: best=9:24:00 survivors=200
# Gen1076: best=9:24:00 survivors=200
# Gen1077: best=9:24:00 survivors=200
# Gen1078: best=9:24:00 survivors=200
# Gen1079: best=9:24:00 survivors=200
# Gen1080: best=9:24:00 survivors=200
# Gen1081: best=9:24:00 survivors=200
# Gen1082: best=9:24:00 survivors=200
# Gen1083: best=9:24:00 survivors=200
# Gen1084: best=9:24:00 survivors=200
# Gen1085: best=9:24:00 survivors=200
# Gen1086: best=9:24:00 survivors=200
# Gen1087: best=9:24:00 survivors=200
# Gen1088: best=9:24:00 survivors=200
# Gen1089: best=9:24:00 survivors=200
# Gen1090: best=9:24:00 survivors=200
# Gen1091: best=9:24:00 survivors=200
# Gen1092: best=9:24:00 survivors=200
# Gen1093: best=9:24:00 survivors=200
# Gen1094: best=9:24:00 survivors=200
# Gen1095: best=9:24:00 survivors=200
# Gen1096: best=9:24:00 survivors=200
# Gen1097: best=9:24:00 survivors=200
# Gen1098: best=9:24:00 survivors=200
# Gen1099: best=9:24:00 survivors=200
# Gen1100: best=9:24:00 survivors=200
# Gen1101: best=9:24:00 survivors=200
# Gen1102: best=9:24:00 survivors=200
# Gen1103: best=9:24:00 survivors=200
# Gen1104: best=9:24:00 survivors=200
# Gen1105: best=9:24:00 survivors=200
# Gen1106: best=9:24:00 survivors=200
# Gen1107: best=9:24:00 survivors=200
# Gen1108: best=9:24:00 survivors=200
# Gen1109: best=9:24:00 survivors=200
# Gen1110: best=9:24:00 survivors=200
# Gen1111: best=9:24:00 survivors=200
# Gen1112: best=9:24:00 survivors=200
# Gen1113: best=9:24:00 survivors=200
# Gen1114: best=9:24:00 survivors=200
# Gen1115: best=9:24:00 survivors=200
# Gen1116: best=9:24:00 survivors=200
# Gen1117: best=9:24:00 survivors=200
# Gen1118: best=9:24:00 survivors=200
# Gen1119: best=9:24:00 survivors=200
# Gen1120: best=9:24:00 survivors=200
# Gen1121: best=9:24:00 survivors=200
# Gen1122: best=9:24:00 survivors=200
# Gen1123: best=9:24:00 survivors=200
# Gen1124: best=9:24:00 survivors=200
# Gen1125: best=9:24:00 survivors=200
# Gen1126: best=9:24:00 survivors=200
# Gen1127: best=9:24:00 survivors=200
# Gen1128: best=9:24:00 survivors=200
# Gen1129: best=9:24:00 survivors=200
# Gen1130: best=9:24:00 survivors=200
# Gen1131: best=9:24:00 survivors=200
# Gen1132: best=9:24:00 survivors=200
# Gen1133: best=9:24:00 survivors=200
# Gen1134: best=9:24:00 survivors=200
# Gen1135: best=9:24:00 survivors=200
# Gen1136: best=9:24:00 survivors=200
# Gen1137: best=9:24:00 survivors=200
# Gen1138: best=9:24:00 survivors=200
# Gen1139: best=9:24:00 survivors=200
# Gen1140: best=9:24:00 survivors=200
# Gen1141: best=9:24:00 survivors=200
# Gen1142: best=9:24:00 survivors=200
# Gen1143: best=9:24:00 survivors=200
# Gen1144: best=9:24:00 survivors=200
# Gen1145: best=9:24:00 survivors=200
# Gen1146: best=9:24:00 survivors=200
# Gen1147: best=9:24:00 survivors=200
# Gen1148: best=9:24:00 survivors=200
# Gen1149: best=9:24:00 survivors=200
# Gen1150: best=9:24:00 survivors=200
# Gen1151: best=9:24:00 survivors=200
# Gen1152: best=9:24:00 survivors=200
# Gen1153: best=9:24:00 survivors=200
# Gen1154: best=9:24:00 survivors=200
# Gen1155: best=9:24:00 survivors=200
# Gen1156: best=9:24:00 survivors=200
# Gen1157: best=9:24:00 survivors=200
# Gen1158: best=9:24:00 survivors=200
# Gen1159: best=9:24:00 survivors=200
# Gen1160: best=9:24:00 survivors=200
# Gen1161: best=9:24:00 survivors=200
# Gen1162: best=9:24:00 survivors=200
# Gen1163: best=9:24:00 survivors=200
# Gen1164: best=9:24:00 survivors=200
# Gen1165: best=9:24:00 survivors=200
# Gen1166: best=9:24:00 survivors=200
# Gen1167: best=9:24:00 survivors=200
# Gen1168: best=9:24:00 survivors=200
# Gen1169: best=9:24:00 survivors=200
# Gen1170: best=9:24:00 survivors=200
# Gen1171: best=9:24:00 survivors=200
# Gen1172: best=9:24:00 survivors=200
# Gen1173: best=9:24:00 survivors=200
# Gen1174: best=9:24:00 survivors=200
# Gen1175: best=9:24:00 survivors=200
# Gen1176: best=9:24:00 survivors=200
# Gen1177: best=9:24:00 survivors=200
# Gen1178: best=9:24:00 survivors=200
# Gen1179: best=9:24:00 survivors=200
# Gen1180: best=9:24:00 survivors=200
# Gen1181: best=9:24:00 survivors=200
# Gen1182: best=9:24:00 survivors=200
# Gen1183: best=9:24:00 survivors=200
# Gen1184: best=9:24:00 survivors=200
# Gen1185: best=9:24:00 survivors=200
# Gen1186: best=9:24:00 survivors=200
# Gen1187: best=9:24:00 survivors=200
# Gen1188: best=9:24:00 survivors=200
# Gen1189: best=9:24:00 survivors=200
# Gen1190: best=9:24:00 survivors=200
# Gen1191: best=9:24:00 survivors=200
# Gen1192: best=9:24:00 survivors=200
# Gen1193: best=9:24:00 survivors=200
# Gen1194: best=9:24:00 survivors=200
# Gen1195: best=9:24:00 survivors=200
# Gen1196: best=9:24:00 survivors=200
# Gen1197: best=9:24:00 survivors=200
# Gen1198: best=9:24:00 survivors=200
# Gen1199: best=9:24:00 survivors=200
# Gen1200: best=9:24:00 survivors=200
# Gen1201: best=9:24:00 survivors=200
# Gen1202: best=9:24:00 survivors=200
# Gen1203: best=9:24:00 survivors=200
# Gen1204: best=9:24:00 survivors=200
# Gen1205: best=9:24:00 survivors=200
# Gen1206: best=9:24:00 survivors=200
# Gen1207: best=9:24:00 survivors=200
# Gen1208: best=9:24:00 survivors=200
# Gen1209: best=9:24:00 survivors=200
# Gen1210: best=9:24:00 survivors=200
# Gen1211: best=9:24:00 survivors=200
# Gen1212: best=9:24:00 survivors=200
# Gen1213: best=9:24:00 survivors=200
# Gen1214: best=9:24:00 survivors=200
# Gen1215: best=9:24:00 survivors=200
# Gen1216: best=9:24:00 survivors=200
# Gen1217: best=9:24:00 survivors=200
# Gen1218: best=9:24:00 survivors=200
# Gen1219: best=9:24:00 survivors=200
# Gen1220: best=9:24:00 survivors=200
# Gen1221: best=9:24:00 survivors=200
# Gen1222: best=9:24:00 survivors=200
# Gen1223: best=9:24:00 survivors=200
# Gen1224: best=9:24:00 survivors=200
# Gen1225: best=9:24:00 survivors=200
# Gen1226: best=9:24:00 survivors=200
# Gen1227: best=9:24:00 survivors=200
# Gen1228: best=9:24:00 survivors=200
# Gen1229: best=9:24:00 survivors=200
# Gen1230: best=9:24:00 survivors=200
# Gen1231: best=9:24:00 survivors=200
# Gen1232: best=9:24:00 survivors=200
# Gen1233: best=9:24:00 survivors=200
# Gen1234: best=9:24:00 survivors=200
# Gen1235: best=9:24:00 survivors=200
# Gen1236: best=9:24:00 survivors=200
# Gen1237: best=9:24:00 survivors=200
# Gen1238: best=9:24:00 survivors=200
# Gen1239: best=9:24:00 survivors=200
# Gen1240: best=9:24:00 survivors=200
# Gen1241: best=9:24:00 survivors=200
# Gen1242: best=9:24:00 survivors=200
# Gen1243: best=9:24:00 survivors=200
# Gen1244: best=9:24:00 survivors=200
# Gen1245: best=9:24:00 survivors=200
# Gen1246: best=9:24:00 survivors=200
# Gen1247: best=9:24:00 survivors=200
# Gen1248: best=9:24:00 survivors=200
# Gen1249: best=9:24:00 survivors=200
# Gen1250: best=9:24:00 survivors=200
# Gen1251: best=9:24:00 survivors=200
# Gen1252: best=9:24:00 survivors=200
# Gen1253: best=9:24:00 survivors=200
# Gen1254: best=9:24:00 survivors=200
# Gen1255: best=9:24:00 survivors=200
# Gen1256: best=9:24:00 survivors=200
# Gen1257: best=9:24:00 survivors=200
# Gen1258: best=9:24:00 survivors=200
# Gen1259: best=9:24:00 survivors=200
# Gen1260: best=9:24:00 survivors=200
# Gen1261: best=9:24:00 survivors=200
# Gen1262: best=9:24:00 survivors=200
# Gen1263: best=9:24:00 survivors=200
# Gen1264: best=9:24:00 survivors=200
# Gen1265: best=9:24:00 survivors=200
# Gen1266: best=9:24:00 survivors=200
# Gen1267: best=9:24:00 survivors=200
# Gen1268: best=9:24:00 survivors=200
# Gen1269: best=9:24:00 survivors=200
# Gen1270: best=9:24:00 survivors=200
# Gen1271: best=9:24:00 survivors=200
# Gen1272: best=9:24:00 survivors=200
# Gen1273: best=9:24:00 survivors=200
# Gen1274: best=9:24:00 survivors=200
# Gen1275: best=9:24:00 survivors=200
# Gen1276: best=9:24:00 survivors=200
# Gen1277: best=9:24:00 survivors=200
# Gen1278: best=9:24:00 survivors=200
# Gen1279: best=9:24:00 survivors=200
# Gen1280: best=9:24:00 survivors=200
# Gen1281: best=9:24:00 survivors=200
# Gen1282: best=9:24:00 survivors=200
# Gen1283: best=9:24:00 survivors=200
# Gen1284: best=9:24:00 survivors=200
# Gen1285: best=9:24:00 survivors=200
# Gen1286: best=9:24:00 survivors=200
# Gen1287: best=9:24:00 survivors=200
# Gen1288: best=9:24:00 survivors=200
# Gen1289: best=9:24:00 survivors=200
# Gen1290: best=9:24:00 survivors=200
# Gen1291: best=9:24:00 survivors=200
# Gen1292: best=9:24:00 survivors=200
# Gen1293: best=9:24:00 survivors=200
# Gen1294: best=9:24:00 survivors=200
# Gen1295: best=9:24:00 survivors=200
# Gen1296: best=9:24:00 survivors=200
# Gen1297: best=9:24:00 survivors=200
# Gen1298: best=9:24:00 survivors=200
# Gen1299: best=9:24:00 survivors=200
# Gen1300: best=9:24:00 survivors=200
# Gen1301: best=9:24:00 survivors=200
# Gen1302: best=9:24:00 survivors=200
# Gen1303: best=9:24:00 survivors=200
# Gen1304: best=9:24:00 survivors=200
# Gen1305: best=9:24:00 survivors=200
# Gen1306: best=9:24:00 survivors=200
# Gen1307: best=9:24:00 survivors=200
# Gen1308: best=9:24:00 survivors=200
# Gen1309: best=9:24:00 survivors=200
# Gen1310: best=9:24:00 survivors=200
# Gen1311: best=9:24:00 survivors=200
# Gen1312: best=9:24:00 survivors=200
# Gen1313: best=9:24:00 survivors=200
# Gen1314: best=9:24:00 survivors=200
# Gen1315: best=9:24:00 survivors=200
# Gen1316: best=9:24:00 survivors=200
# Gen1317: best=9:24:00 survivors=200
# Gen1318: best=9:24:00 survivors=200
# Gen1319: best=9:24:00 survivors=200
# Gen1320: best=9:24:00 survivors=200
# Gen1321: best=9:24:00 survivors=200
# Gen1322: best=9:24:00 survivors=200
# Gen1323: best=9:24:00 survivors=200
# Gen1324: best=9:24:00 survivors=200
# Gen1325: best=9:24:00 survivors=200
# Gen1326: best=9:24:00 survivors=200
# Gen1327: best=9:24:00 survivors=200
# Gen1328: best=9:24:00 survivors=200
# Gen1329: best=9:24:00 survivors=200
# Gen1330: best=9:24:00 survivors=200
# Gen1331: best=9:24:00 survivors=200
# Gen1332: best=9:24:00 survivors=200
# Gen1333: best=9:24:00 survivors=200
# Gen1334: best=9:24:00 survivors=200
# Gen1335: best=9:24:00 survivors=200
# Gen1336: best=9:24:00 survivors=200
# Gen1337: best=9:24:00 survivors=200
# Gen1338: best=9:24:00 survivors=200
# Gen1339: best=9:24:00 survivors=200
# Gen1340: best=9:24:00 survivors=200
# Gen1341: best=9:24:00 survivors=200
# Gen1342: best=9:24:00 survivors=200
# Gen1343: best=9:24:00 survivors=200
# Gen1344: best=9:24:00 survivors=200
# Gen1345: best=9:24:00 survivors=200
# Gen1346: best=9:24:00 survivors=200
# Gen1347: best=9:24:00 survivors=200
# Gen1348: best=9:24:00 survivors=200
# Gen1349: best=9:24:00 survivors=200
# Gen1350: best=9:24:00 survivors=200
# Gen1351: best=9:24:00 survivors=200
# Gen1352: best=9:24:00 survivors=200
# Gen1353: best=9:24:00 survivors=200
# Gen1354: best=9:24:00 survivors=200
# Gen1355: best=9:24:00 survivors=200
# Gen1356: best=9:24:00 survivors=200
# Gen1357: best=9:24:00 survivors=200
# Gen1358: best=9:24:00 survivors=200
# ...
# Gen1957: best=9:24:00 survivors=200
# Gen1958: best=9:24:00 survivors=200
# Gen1959: best=9:24:00 survivors=200
# Gen1960: best=9:24:00 survivors=200
# Gen1961: best=9:24:00 survivors=200
# Gen1962: best=9:24:00 survivors=200
# Gen1963: best=9:24:00 survivors=200
# Gen1964: best=9:24:00 survivors=200
# Gen1965: best=9:24:00 survivors=200
# Gen1966: best=9:24:00 survivors=200
# Gen1967: best=9:24:00 survivors=200
# Gen1968: best=9:24:00 survivors=200
# Gen1969: best=9:24:00 survivors=200
# Gen1970: best=9:24:00 survivors=200
# Gen1971: best=9:24:00 survivors=200
# Gen1972: best=9:24:00 survivors=200
# Gen1973: best=9:24:00 survivors=200
# Gen1974: best=9:24:00 survivors=200
# Gen1975: best=9:24:00 survivors=200
# Gen1976: best=9:24:00 survivors=200
# Gen1977: best=9:24:00 survivors=200
# Gen1978: best=9:24:00 survivors=200
# Gen1979: best=9:24:00 survivors=200
# Gen1980: best=9:24:00 survivors=200
# Gen1981: best=9:24:00 survivors=200
# Gen1982: best=9:24:00 survivors=200
# Gen1983: best=9:24:00 survivors=200
# Gen1984: best=9:24:00 survivors=200
# Gen1985: best=9:24:00 survivors=200
# Gen1986: best=9:24:00 survivors=200
# Gen1987: best=9:24:00 survivors=200
# Gen1988: best=9:24:00 survivors=200
# Gen1989: best=9:24:00 survivors=200
# Gen1990: best=9:24:00 survivors=200
# Gen1991: best=9:24:00 survivors=200
# Gen1992: best=9:24:00 survivors=200
# Gen1993: best=9:24:00 survivors=200
# Gen1994: best=9:24:00 survivors=200
# Gen1995: best=9:24:00 survivors=200
# Gen1996: best=9:24:00 survivors=200
# Gen1997: best=9:24:00 survivors=200
# Gen1998: best=9:24:00 survivors=200
# Gen1999: best=9:24:00 survivors=200
# Gen2000: best=9:24:00 survivors=200
# Gen2001: best=9:24:00 survivors=200
# Gen2002: best=9:24:00 survivors=200
# Gen2003: best=9:24:00 survivors=200
# Gen2004: best=9:24:00 survivors=200
# Gen2005: best=9:24:00 survivors=200
# Gen2006: best=9:24:00 survivors=200
# Gen2007: best=9:24:00 survivors=200
# Gen2008: best=9:24:00 survivors=200
# Gen2009: best=9:24:00 survivors=200
# Gen2010: best=9:24:00 survivors=200
# Gen2011: best=9:24:00 survivors=200
# Gen2012: best=9:24:00 survivors=200
# Gen2013: best=9:24:00 survivors=200
# Gen2014: best=9:24:00 survivors=200
# Gen2015: best=9:24:00 survivors=200
# Gen2016: best=9:24:00 survivors=200
# Gen2017: best=9:24:00 survivors=200
# Gen2018: best=9:24:00 survivors=200
# Gen2019: best=9:24:00 survivors=200
# Gen2020: best=9:24:00 survivors=200
# Gen2021: best=9:24:00 survivors=200
# Gen2022: best=9:24:00 survivors=200
# Gen2023: best=9:24:00 survivors=200
# Gen2024: best=9:24:00 survivors=200
# Gen2025: best=9:24:00 survivors=200
# Gen2026: best=9:24:00 survivors=200
# Gen2027: best=9:24:00 survivors=200
# Gen2028: best=9:24:00 survivors=200
# Gen2029: best=9:24:00 survivors=200
# Gen2030: best=9:24:00 survivors=200
# Gen2031: best=9:24:00 survivors=200
# Gen2032: best=9:24:00 survivors=200
# Gen2033: best=9:24:00 survivors=200
# Gen2034: best=9:24:00 survivors=200
# Gen2035: best=9:24:00 survivors=200
# Gen2036: best=9:24:00 survivors=200
# Gen2037: best=9:24:00 survivors=200
# Gen2038: best=9:24:00 survivors=200
# Gen2039: best=9:24:00 survivors=200
# Gen2040: best=9:24:00 survivors=200
# Gen2041: best=9:24:00 survivors=200
# Gen2042: best=9:24:00 survivors=200
# Gen2043: best=9:24:00 survivors=200
# Gen2044: best=9:24:00 survivors=200
# Gen2045: best=9:24:00 survivors=200
# Gen2046: best=9:24:00 survivors=200
# Gen2047: best=9:24:00 survivors=200
# Gen2048: best=9:24:00 survivors=200
# Gen2049: best=9:24:00 survivors=200
# Gen2050: best=9:24:00 survivors=200
# Gen2051: best=9:24:00 survivors=200
# Gen2052: best=9:24:00 survivors=200
# Gen2053: best=9:24:00 survivors=200
# Gen2054: best=9:24:00 survivors=200
# Gen2055: best=9:24:00 survivors=200
# Gen2056: best=9:24:00 survivors=200
# Gen2057: best=9:24:00 survivors=200
# Gen2058: best=9:24:00 survivors=200
# Gen2059: best=9:24:00 survivors=200
# Gen2060: best=9:24:00 survivors=200
# Gen2061: best=9:24:00 survivors=200
# Gen2062: best=9:24:00 survivors=200
# Gen2063: best=9:24:00 survivors=200
# Gen2064: best=9:24:00 survivors=200
# Gen2065: best=9:24:00 survivors=200
# Gen2066: best=9:24:00 survivors=200
# Gen2067: best=9:24:00 survivors=200
# Gen2068: best=9:24:00 survivors=200
# Gen2069: best=9:24:00 survivors=200
# Gen2070: best=9:24:00 survivors=200
# Gen2071: best=9:24:00 survivors=200
# Gen2072: best=9:24:00 survivors=200
# Gen2073: best=9:24:00 survivors=200
# Gen2074: best=9:24:00 survivors=200
# Gen2075: best=9:24:00 survivors=200
# Gen2076: best=9:24:00 survivors=200
# Gen2077: best=9:24:00 survivors=200
# Gen2078: best=9:24:00 survivors=200
# Gen2079: best=9:24:00 survivors=200
# Gen2080: best=9:24:00 survivors=200
# Gen2081: best=9:24:00 survivors=200
# Gen2082: best=9:24:00 survivors=200
# Gen2083: best=9:24:00 survivors=200
# Gen2084: best=9:24:00 survivors=200
# Gen2085: best=9:24:00 survivors=200
# Gen2086: best=9:24:00 survivors=200
# Gen2087: best=9:24:00 survivors=200
# Gen2088: best=9:24:00 survivors=200
# Gen2089: best=9:24:00 survivors=200
# Gen2090: best=9:24:00 survivors=200
# Gen2091: best=9:24:00 survivors=200
# Gen2092: best=9:24:00 survivors=200
# Gen2093: best=9:24:00 survivors=200
# Gen2094: best=9:24:00 survivors=200
# Gen2095: best=9:24:00 survivors=200
# Gen2096: best=9:24:00 survivors=200
# Gen2097: best=9:24:00 survivors=200
# Gen2098: best=9:24:00 survivors=200
# Gen2099: best=9:24:00 survivors=200
# Gen2100: best=9:24:00 survivors=200
# Gen2101: best=9:24:00 survivors=200
# Gen2102: best=9:24:00 survivors=200
# Gen2103: best=9:24:00 survivors=200
# Gen2104: best=9:24:00 survivors=200
# Gen2105: best=9:24:00 survivors=200
# Gen2106: best=9:24:00 survivors=200
# Gen2107: best=9:24:00 survivors=200
# Gen2108: best=9:24:00 survivors=200
# Gen2109: best=9:24:00 survivors=200
# Gen2110: best=9:24:00 survivors=200
# Gen2111: best=9:24:00 survivors=200
# Gen2112: best=9:24:00 survivors=200
# Gen2113: best=9:24:00 survivors=200
# Gen2114: best=9:24:00 survivors=200
# Gen2115: best=9:24:00 survivors=200
# Gen2116: best=9:24:00 survivors=200
# Gen2117: best=9:24:00 survivors=200
# Gen2118: best=9:24:00 survivors=200
# Gen2119: best=9:24:00 survivors=200
# Gen2120: best=9:24:00 survivors=200
# Gen2121: best=9:24:00 survivors=200
# Gen2122: best=9:24:00 survivors=200
# Gen2123: best=9:24:00 survivors=200
# Gen2124: best=9:24:00 survivors=200
# Gen2125: best=9:24:00 survivors=200
# Gen2126: best=9:24:00 survivors=200
# Gen2127: best=9:24:00 survivors=200
# Gen2128: best=9:24:00 survivors=200
# Gen2129: best=9:24:00 survivors=200
# Gen2130: best=9:24:00 survivors=200
# Gen2131: best=9:24:00 survivors=200
# Gen2132: best=9:24:00 survivors=200
# Gen2133: best=9:24:00 survivors=200
# Gen2134: best=9:24:00 survivors=200
# Gen2135: best=9:24:00 survivors=200
# Gen2136: best=9:24:00 survivors=200
# Gen2137: best=9:24:00 survivors=200
# Gen2138: best=9:24:00 survivors=200
# Gen2139: best=9:24:00 survivors=200
# Gen2140: best=9:24:00 survivors=200
# Gen2141: best=9:24:00 survivors=200
# Gen2142: best=9:24:00 survivors=200
# Gen2143: best=9:24:00 survivors=200
# Gen2144: best=9:24:00 survivors=200
# Gen2145: best=9:24:00 survivors=200
# Gen2146: best=9:24:00 survivors=200
# Gen2147: best=9:24:00 survivors=200
# Gen2148: best=9:24:00 survivors=200
# Gen2149: best=9:24:00 survivors=200
# Gen2150: best=9:24:00 survivors=200
# Gen2151: best=9:24:00 survivors=200
# Gen2152: best=9:24:00 survivors=200
# Gen2153: best=9:24:00 survivors=200
# Gen2154: best=9:24:00 survivors=200
# Gen2155: best=9:24:00 survivors=200
# Gen2156: best=9:24:00 survivors=200
# Gen2157: best=9:24:00 survivors=200
# Gen2158: best=9:24:00 survivors=200
# Gen2159: best=9:24:00 survivors=200
# Gen2160: best=9:24:00 survivors=200
# Gen2161: best=9:24:00 survivors=200
# Gen2162: best=9:24:00 survivors=200
# Gen2163: best=9:24:00 survivors=200
# Gen2164: best=9:24:00 survivors=200
# Gen2165: best=9:24:00 survivors=200
# Gen2166: best=9:24:00 survivors=200
# Gen2167: best=9:24:00 survivors=200
# Gen2168: best=9:24:00 survivors=200
# Gen2169: best=9:24:00 survivors=200
# Gen2170: best=9:24:00 survivors=200
# Gen2171: best=9:24:00 survivors=200
# Gen2172: best=9:24:00 survivors=200
# Gen2173: best=9:24:00 survivors=200
# Gen2174: best=9:24:00 survivors=200
# Gen2175: best=9:24:00 survivors=200
# Gen2176: best=9:24:00 survivors=200
# Gen2177: best=9:24:00 survivors=200
# Gen2178: best=9:24:00 survivors=200
# Gen2179: best=9:24:00 survivors=200
# Gen2180: best=9:24:00 survivors=200
# Gen2181: best=9:24:00 survivors=200
# Gen2182: best=9:24:00 survivors=200
# Gen2183: best=9:24:00 survivors=200
# Gen2184: best=9:24:00 survivors=200
# Gen2185: best=9:24:00 survivors=200
# Gen2186: best=9:24:00 survivors=200
# Gen2187: best=9:24:00 survivors=200
# Gen2188: best=9:24:00 survivors=200
# Gen2189: best=9:24:00 survivors=200
# Gen2190: best=9:24:00 survivors=200
# Gen2191: best=9:24:00 survivors=200
# Gen2192: best=9:24:00 survivors=200
# Gen2193: best=9:24:00 survivors=200
# Gen2194: best=9:24:00 survivors=200
# Gen2195: best=9:24:00 survivors=200
# Gen2196: best=9:24:00 survivors=200
# Gen2197: best=9:24:00 survivors=200
# Gen2198: best=9:24:00 survivors=200
# Gen2199: best=9:24:00 survivors=200
# Gen2200: best=9:24:00 survivors=200
# Gen2201: best=9:24:00 survivors=200
# Gen2202: best=9:24:00 survivors=200
# Gen2203: best=9:24:00 survivors=200
# Gen2204: best=9:24:00 survivors=200
# Gen2205: best=9:24:00 survivors=200
# Gen2206: best=9:24:00 survivors=200
# Gen2207: best=9:24:00 survivors=200
# Gen2208: best=9:24:00 survivors=200
# Gen2209: best=9:24:00 survivors=200
# Gen2210: best=9:24:00 survivors=200
# Gen2211: best=9:24:00 survivors=200
# Gen2212: best=9:24:00 survivors=200
# Gen2213: best=9:24:00 survivors=200
# Gen2214: best=9:24:00 survivors=200
# Gen2215: best=9:24:00 survivors=200
# Gen2216: best=9:24:00 survivors=200
# Gen2217: best=9:24:00 survivors=200
# Gen2218: best=9:24:00 survivors=200
# Gen2219: best=9:24:00 survivors=200
# Gen2220: best=9:24:00 survivors=200
# Gen2221: best=9:24:00 survivors=200
# Gen2222: best=9:24:00 survivors=200
# Gen2223: best=9:24:00 survivors=200
# Gen2224: best=9:24:00 survivors=200
# Gen2225: best=9:24:00 survivors=200
# Gen2226: best=9:24:00 survivors=200
# Gen2227: best=9:24:00 survivors=200
# Gen2228: best=9:24:00 survivors=200
# Gen2229: best=9:24:00 survivors=200
# Gen2230: best=9:24:00 survivors=200
# Gen2231: best=9:24:00 survivors=200
# Gen2232: best=9:24:00 survivors=200
# Gen2233: best=9:24:00 survivors=200
# Gen2234: best=9:24:00 survivors=200
# Gen2235: best=9:24:00 survivors=200
# Gen2236: best=9:24:00 survivors=200
# Gen2237: best=9:24:00 survivors=200
# Gen2238: best=9:24:00 survivors=200
# Gen2239: best=9:24:00 survivors=200
# Gen2240: best=9:24:00 survivors=200
# Gen2241: best=9:24:00 survivors=200
# Gen2242: best=9:24:00 survivors=200
# Gen2243: best=9:24:00 survivors=200
# Gen2244: best=9:24:00 survivors=200
# Gen2245: best=9:24:00 survivors=200
# Gen2246: best=9:24:00 survivors=200
# Gen2247: best=9:24:00 survivors=200
# Gen2248: best=9:24:00 survivors=200
# Gen2249: best=9:24:00 survivors=200
# Gen2250: best=9:24:00 survivors=200
# Gen2251: best=9:24:00 survivors=200
# Gen2252: best=9:24:00 survivors=200
# Gen2253: best=9:24:00 survivors=200
# Gen2254: best=9:24:00 survivors=200
# Gen2255: best=9:24:00 survivors=200
# Gen2256: best=9:24:00 survivors=200
# Gen2257: best=9:24:00 survivors=200
# Gen2258: best=9:24:00 survivors=200
# Gen2259: best=9:24:00 survivors=200
# Gen2260: best=9:24:00 survivors=200
# Gen2261: best=9:24:00 survivors=200
# Gen2262: best=9:24:00 survivors=200
# Gen2263: best=9:24:00 survivors=200
# Gen2264: best=9:24:00 survivors=200
# Gen2265: best=9:24:00 survivors=200
# Gen2266: best=9:24:00 survivors=200
# Gen2267: best=9:24:00 survivors=200
# Gen2268: best=9:24:00 survivors=200
# Gen2269: best=9:24:00 survivors=200
# Gen2270: best=9:24:00 survivors=200
# Gen2271: best=9:24:00 survivors=200
# Gen2272: best=9:24:00 survivors=200
# Gen2273: best=9:24:00 survivors=200
# Gen2274: best=9:24:00 survivors=200
# Gen2275: best=9:24:00 survivors=200
# Gen2276: best=9:24:00 survivors=200
# Gen2277: best=9:24:00 survivors=200
# Gen2278: best=9:24:00 survivors=200
# Gen2279: best=9:24:00 survivors=200
# Gen2280: best=9:24:00 survivors=200
# Gen2281: best=9:24:00 survivors=200
# Gen2282: best=9:24:00 survivors=200
# Gen2283: best=9:24:00 survivors=200
# Gen2284: best=9:24:00 survivors=200
# Gen2285: best=9:24:00 survivors=200
# Gen2286: best=9:24:00 survivors=200
# Gen2287: best=9:24:00 survivors=200
# Gen2288: best=9:24:00 survivors=200
# Gen2289: best=9:24:00 survivors=200
# Gen2290: best=9:24:00 survivors=200
# Gen2291: best=9:24:00 survivors=200
# Gen2292: best=9:24:00 survivors=200
# Gen2293: best=9:24:00 survivors=200
# Gen2294: best=9:24:00 survivors=200
# Gen2295: best=9:24:00 survivors=200
# Gen2296: best=9:24:00 survivors=200
# Gen2297: best=9:24:00 survivors=200
# Gen2298: best=9:24:00 survivors=200
# Gen2299: best=9:24:00 survivors=200
# Gen2300: best=9:24:00 survivors=200
# Gen2301: best=9:24:00 survivors=200
# Gen2302: best=9:24:00 survivors=200
# Gen2303: best=9:24:00 survivors=200
# Gen2304: best=9:24:00 survivors=200
# Gen2305: best=9:24:00 survivors=200
# Gen2306: best=9:24:00 survivors=200
# Gen2307: best=9:24:00 survivors=200
# Gen2308: best=9:24:00 survivors=200
# Gen2309: best=9:24:00 survivors=200
# Gen2310: best=9:24:00 survivors=200
# Gen2311: best=9:24:00 survivors=200
# Gen2312: best=9:24:00 survivors=200
# Gen2313: best=9:24:00 survivors=200
# Gen2314: best=9:24:00 survivors=200
# Gen2315: best=9:24:00 survivors=200
# Gen2316: best=9:24:00 survivors=200
# Gen2317: best=9:24:00 survivors=200
# Gen2318: best=9:24:00 survivors=200
# Gen2319: best=9:24:00 survivors=200
# Gen2320: best=9:24:00 survivors=200
# Gen2321: best=9:24:00 survivors=200
# Gen2322: best=9:24:00 survivors=200
# Gen2323: best=9:24:00 survivors=200
# Gen2324: best=9:24:00 survivors=200
# Gen2325: best=9:24:00 survivors=200
# Gen2326: best=9:24:00 survivors=200
# Gen2327: best=9:24:00 survivors=200
# Gen2328: best=9:24:00 survivors=200
# Gen2329: best=9:24:00 survivors=200
# Gen2330: best=9:24:00 survivors=200
# Gen2331: best=9:24:00 survivors=200
# Gen2332: best=9:24:00 survivors=200
# Gen2333: best=9:24:00 survivors=200
# Gen2334: best=9:24:00 survivors=200
# Gen2335: best=9:24:00 survivors=200
# Gen2336: best=9:24:00 survivors=200
# Gen2337: best=9:24:00 survivors=200
# Gen2338: best=9:24:00 survivors=200
# Gen2339: best=9:24:00 survivors=200
# Gen2340: best=9:24:00 survivors=200
# Gen2341: best=9:24:00 survivors=200
# Gen2342: best=9:24:00 survivors=200
# Gen2343: best=9:24:00 survivors=200
# Gen2344: best=9:24:00 survivors=200
# > simulating ant#116
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 120
#     116     return best_ant_path
#     118 MIN_CHANGE_BUFFER_SECONDS = 30
# --> 120 ant_colony_opt(
#     121     gt_parse_time("9:00:00", lookup_day),
#     122     network.search_stops("Bahnhofplatz/HB")[0],
#     123     num_ants=200,
#     124     generations=999999999,
#     125     reset_pheromones=True,
#     126     pheromone_strength=50,
#     127     pheromone_decay_factor=0.9,
#     128     min_pheromone=0.1,
#     129     distance_power=2
#     130 )
#
# Cell In[21], line 89, in ant_colony_opt(start_time, start_stop, num_ants, generations, reset_pheromones, pheromone_strength, pheromone_decay_factor, min_pheromone, distance_power)
#      86 ant_decision_list: list[list[tuple[TramStop, TramStop, datetime]]] = []
#      88 for ant_index in range(num_ants):
# ---> 89     ant_result = simulate_ant(ant_index)
#      90     if ant_result is not None:
#      91         ant_path, ant_decisions = ant_result
#
# Cell In[21], line 53, in ant_colony_opt.<locals>.simulate_ant(ant_index)
#      50 curr_time = curr_path.arrival_times[-1]
#      52 available_stops = list(remaining_stops)
# ---> 53 available_weights = [
#      54     pheromone_map[curr_stop][stop] * 100000
#      55     / (precomputed_distance_matrix[curr_stop][stop] ** distance_power)
#      56     for stop in available_stops
#      57 ]
#      59 new_stop = random_choice_distribution(available_stops, available_weights)
#      61 try:
#
# Cell In[21], line 54, in <listcomp>(.0)
#      50 curr_time = curr_path.arrival_times[-1]
#      52 available_stops = list(remaining_stops)
#      53 available_weights = [
# ---> 54     pheromone_map[curr_stop][stop] * 100000
#      55     / (precomputed_distance_matrix[curr_stop][stop] ** distance_power)
#      56     for stop in available_stops
#      57 ]
#      59 new_stop = random_choice_distribution(available_stops, available_weights)
#      61 try:
#
# KeyboardInterrupt:

# %%
"load existing path and simulate patzer"

path = TramPath.load("ant.2025-01-28--9-06-18.txt", network)

start_time = path.departure_times[0]
patzer_prob = 0.01
patzer_active = False
curr_path = TramPath()

MIN_CHANGE_BUFFER_SECONDS = 0

curr_stop = path.stops[0]
curr_time = path.arrival_times[0]
curr_tram = None
for stop, arrival_time, departure_time, tram_name in path.zip():
    if patzer_active:
        next_stop = stop
        new_path = calc_dijkstra_path_between(curr_time, curr_stop, stop, curr_tram)
        curr_path.add_path(new_path)
        curr_stop = stop
        curr_tram = curr_path.transportation_names[-2]
        curr_time = new_path.arrival_times[-1]

    else:
        curr_stop = stop
        curr_time = arrival_time
        curr_tram = tram_name
        curr_path.add_stop(stop, arrival_time, departure_time, tram_name)

    if random.random() < patzer_prob:
        patzer_active = True
        curr_time += timedelta(minutes=5)
        print(f"simulated patzer at {curr_time} in {curr_stop}")

    # print(curr_time, curr_stop)

print()
curr_path.print_summary()
# Out:
# simulated patzer at 2025-01-28 09:21:06 in Grimselstrasse
# simulated patzer at 2025-01-28 09:54:48 in Fellenbergstrasse
# simulated patzer at 2025-01-28 11:17:30 in Bahnhof Altstetten N K
# simulated patzer at 2025-01-28 17:38:54 in Laubegg
#
# Start: Schlieren, Geissweid
# Destination: Zürich, Seebach
# Total Time: 9:34:30
# Start Time: 2025-01-28 09:05:48
# Total Stops: 305

# %%
"optimize heuristic weights to find optimal nearest neighbour search path"

import random, numpy
from functools import cached_property

start_stop = network.search_stops("Letzi")[0]
start_time = gt_parse_time("9:45:00", lookup_day)

MIN_TIME_DELTA = timedelta(hours=9)

class StopWeighting:

    def __init__(self, weights=None):
        if weights is None:
            self.weights = tuple(0 for _ in range(len(heuristic_names)))
        else:
            self.weights = tuple(weights)
            assert len(self.weights) == len(heuristic_names)

    def mutate(self, mutation_chance: float, mutation_rate: float) -> "StopWeighting":
        new_weights = list(self.weights)
        for i in range(len(self.weights)):
            if random.random() < mutation_chance:
                new_weights[i] = self.weights[i] + numpy.random.normal(0, 1) * mutation_rate
        return StopWeighting(new_weights)
    
    def __repr__(self):
        return f"{self.__class__.__name__}({self.weights!r})"
    
    def __str__(self):
        return repr(self)

    def copy(self):
        return StopWeighting(self.weights)
    
    @classmethod
    def zero(cls):
        return StopWeighting()
    
    @classmethod
    def random(cls):
        return StopWeighting([
            numpy.random.normal(0, 1)
            for _ in range(len(heuristic_names))
        ])

    def make_weight_func(self):
        def get_weight(stop):
            return sum(
                (self.weights[i] * 100) * heuristic_map[stop][h]
                for i, h in enumerate(heuristic_names)
            )
        return get_weight
    
    @cached_property
    def weighted_path(self) -> TramPath:
        try:
            return calc_nearest_neighbor_search(
                start_stop, start_time, self.make_weight_func()
            )
        except NoConnectionsLeftException:
            return None
    
    def calc_score(self) -> float:
        if self.weighted_path is not None:
            delta = self.weighted_path.time_delta() - MIN_TIME_DELTA
            return (10000 / delta.total_seconds()) ** 4
        else:
            return 0
    
    def __hash__(self):
        return hash(self.weights)

population = [
    StopWeighting.random()
    for i in range(100)
]

best_genetic_path = None
best_genetic_delta = None

print(f"Starting Genetic Algorithm population_size={len(population)}")
for gen_index in range(1000):
    # evaluation
    evaluations = {
        weighting: weighting.calc_score()
        for weighting in population
    }

    survivor_count = sum(e > 0 for e in evaluations.values())

    # selection
    population.sort(key=lambda w: evaluations[w], reverse=True)
    parents = population[:1000]
    parent_evaluations = [evaluations[p] for p in parents]
    best = population[0]

    # update global best
    if best_genetic_delta is None or best.weighted_path.time_delta() < best_genetic_delta:
        best_genetic_delta = best.weighted_path.time_delta()
        best_genetic_path = best.weighted_path

    # reproduction and mutation
    for i in range(5, len(population)):
        random_parent = random_choice_distribution(parents, parent_evaluations)
        population[i] = random_parent.mutate(0.15, 1 / (gen_index + 1) + 0.15)
        
    print(f"Gen{gen_index + 1}: s={survivor_count} {best_genetic_delta}, {best}")
# Out:
# Starting Genetic Algorithm population_size=100
# Gen1: s=100 9:55:12, StopWeighting((0.46629174610144386, -0.2556126756723924, -1.2010703460147625, 0.9297278587584765, 1.6839636433723733, -1.2141848659030292, -0.4475748612218616))
# Gen2: s=100 9:55:12, StopWeighting((0.46629174610144386, -0.2556126756723924, -1.2010703460147625, 0.9297278587584765, 1.6839636433723733, -1.2141848659030292, -0.4475748612218616))
# Gen3: s=100 9:55:12, StopWeighting((0.46629174610144386, -0.2556126756723924, -1.2010703460147625, 0.9297278587584765, 1.6839636433723733, -1.2141848659030292, -0.4475748612218616))
# Gen4: s=100 9:46:36, StopWeighting((-0.42146203313059943, 1.9636927685907308, -0.5724807890519013, 0.3234215993226669, -0.38499995237431434, 1.5971136949552038, 0.09031202093353646))
# Gen5: s=100 9:46:36, StopWeighting((-0.42146203313059943, 1.9636927685907308, -0.5724807890519013, 0.3234215993226669, -0.38499995237431434, 1.5971136949552038, 0.09031202093353646))
# Gen6: s=100 9:46:36, StopWeighting((-0.42146203313059943, 1.9636927685907308, -0.5724807890519013, 0.3234215993226669, -0.38499995237431434, 1.5971136949552038, 0.09031202093353646))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 85
#      82 print(f"Starting Genetic Algorithm population_size={len(population)}")
#      83 for gen_index in range(1000):
#      84     # evaluation
# ---> 85     evaluations = {
#      86         weighting: weighting.calc_score()
#      87         for weighting in population
#      88     }
#      90     survivor_count = sum(e > 0 for e in evaluations.values())
#      92     # selection
#
# Cell In[34], line 86, in <dictcomp>(.0)
#      82 print(f"Starting Genetic Algorithm population_size={len(population)}")
#      83 for gen_index in range(1000):
#      84     # evaluation
#      85     evaluations = {
# ---> 86         weighting: weighting.calc_score()
#      87         for weighting in population
#      88     }
#      90     survivor_count = sum(e > 0 for e in evaluations.values())
#      92     # selection
#
# Cell In[34], line 65, in StopWeighting.calc_score(self)
#      64 def calc_score(self) -> float:
# ---> 65     if self.weighted_path is not None:
#      66         delta = self.weighted_path.time_delta() - MIN_TIME_DELTA
#      67         return (10000 / delta.total_seconds()) ** 4
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# Cell In[34], line 58, in StopWeighting.weighted_path(self)
#      55 @cached_property
#      56 def weighted_path(self) -> TramPath:
#      57     try:
# ---> 58         return calc_nearest_neighbor_search(
#      59             start_stop, start_time, self.make_weight_func()
#      60         )
#      61     except NoConnectionsLeftException:
#      62         return None
#
# Cell In[4], line 14, in calc_nearest_neighbor_search(start_stop, start_time, weight_func)
#      12 curr_tram = None
#      13 while len(unvisited_stops) > 0:
# ---> 14     new_path = calc_dijkstra_path_to(curr_time, curr_stop, destination_criterium, start_tram=curr_tram, weight_func=weight_func)
#      15     curr_time = new_path.arrival_times[-1]
#      17     visit_count += 1
#
# Cell In[3], line 26, in calc_dijkstra_path_to(start_time, start, destination_criterium, start_tram, weight_func)
#      23 if destination_criterium(stop):
#      24     return prev_stops
# ---> 26 connections = stop.get_departures_after(curr_time)
#      27 for connection in connections:
#      28     wait_seconds = (connection.arrival_time - curr_time).total_seconds()
#
# File c:\Users\noelf\OneDrive\Dokumente\programming-noel\ipynb\zurich-trams\tramnetwork.py:365, in TramStop.get_departures_after(self, time)
#     364 def get_departures_after(self, time: datetime) -> list[TramPath]:
# --> 365     return [
#     366         c for c in self.connections
#     367         if c.departure_times[0] >= time
#     368     ]
#
# File c:\Users\noelf\OneDrive\Dokumente\programming-noel\ipynb\zurich-trams\tramnetwork.py:367, in <listcomp>(.0)
#     364 def get_departures_after(self, time: datetime) -> list[TramPath]:
#     365     return [
#     366         c for c in self.connections
# --> 367         if c.departure_times[0] >= time
#     368     ]
#
# KeyboardInterrupt:

# %%
"save genetic opt result"

name = "genetic-opt"
best_genetic_path.save(name)
best_genetic_path.save_image(name)
# Out:
# 'genetic-opt.2025-01-28--9-32-30.png'

# %%
"load optimal ttsp path and optimize with timetables"

# cache the path generation as it will be called MANY times with similar arguments!
from functools import cache
@cache
def get_path(t: datetime, a: TramStop, b: TramStop, c: TramName) -> TramPath:
    return calc_dijkstra_path_between(t, a, b, start_tram=c)

# load optimized loop (from using traditional tsp)
with open("graph-exports/optimal-ttsp-loop.txt", "r", encoding="utf-8") as file:
    station_names = [l for l in file.read().split("\n") if l]
optimal_ttsp_stops = [network.search_stops(n)[0] for n in station_names]

# remove duplicate end/start
if optimal_ttsp_stops[0] == optimal_ttsp_stops[-1]:
    optimal_ttsp_stops.pop()

def implement_path_from_stops(start_time: datetime, stops: list[TramStop]) -> TramPath:
    "generate a path following the <stops> parameter from a given <start_time>"
    curr_path = TramPath()
    curr_tram = None
    visited_stops = {stops[0]}

    curr_path.add_stop(stops[0], start_time)
    
    for i, next_stop in enumerate(stops[1:]):
        curr_time = curr_path.arrival_times[-1]
        curr_stop = curr_path.stops[-1]

        try:
            new_path = get_path(
                curr_time,
                curr_stop,
                next_stop,
                curr_tram
            )
        except NoConnectionsLeftException:
            return None
        
        curr_path.add_path(new_path)
        curr_tram = curr_path.transportation_names[-2]

        visited_stops.update(new_path.stops)

        if len(visited_stops) == len(network.stops):
            return curr_path

# Start Parameters (Start of Search and Min Change Buffer)
start_time = gt_parse_time("05:00:00", lookup_day)
MIN_CHANGE_BUFFER_SECONDS = 30

# utility to rotate the stops list by given index (n)
def rotate_list(lst: list, n: int) -> list:
    return lst[n:] + lst[:n]

# keep track of current best track
best_path: TramPath = None

# generate path for every possible combination of time and rotation of stops
print("Starting...", end="\r")
for time_i in range(60 * 12):
    path_start_time = start_time + timedelta(minutes=time_i)

    for rotation_i in range(len(optimal_ttsp_stops)):
        rotated_stops = rotate_list(optimal_ttsp_stops, rotation_i)
        path = implement_path_from_stops(path_start_time, rotated_stops)

        if path is None:
            continue
        
        if best_path is None or best_path.time_delta() > path.time_delta():
            best_path = path

    print(f"c={time_i:03} t={best_path.departure_times[0]} d={best_path.time_delta()} start: <{best_path.stops[0]}> end: <{best_path.stops[-1]}>", end="\r")

# show best
print("Finished.                                                 ")
best_path.print_summary()
# Out:
# c=609 t=2025-01-28 14:17:00 d=9:21:42 start: <Werdhölzli> end: <Frankental>stetten N K>>u>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 62
#      60 for rotation_i in range(len(optimal_ttsp_stops)):
#      61     rotated_stops = rotate_list(optimal_ttsp_stops, rotation_i)
# ---> 62     path = implement_path_from_stops(path_start_time, rotated_stops)
#      64     if path is None:
#      65         continue
#
# Cell In[45], line 30, in implement_path_from_stops(start_time, stops)
#      27 curr_stop = curr_path.stops[-1]
#      29 try:
# ---> 30     new_path = get_path(
#      31         curr_time,
#      32         curr_stop,
#      33         next_stop,
#      34         curr_tram
#      35     )
#      36 except NoConnectionsLeftException:
#      37     return None
#
# Cell In[45], line 7, in get_path(t, a, b, c)
#       5 @cache
#       6 def get_path(t: datetime, a: TramStop, b: TramStop, c: TramName) -> TramPath:
# ----> 7     return calc_dijkstra_path_between(t, a, b, start_tram=c)
#
# Cell In[3], line 65, in calc_dijkstra_path_between(start_time, start, destination, start_tram, weight_func)
#      62 def calc_dijkstra_path_between(start_time: datetime, start: TramStop, destination: TramStop,
#      63                                start_tram: TramName=None, weight_func=None) -> TramPath:
#      64     destination_criterium = lambda stop: stop == destination
# ---> 65     return calc_dijkstra_path_to(start_time, start, destination_criterium, start_tram=start_tram, weight_func=weight_func)
#
# Cell In[3], line 26, in calc_dijkstra_path_to(start_time, start, destination_criterium, start_tram, weight_func)
#      23 if destination_criterium(stop):
#      24     return prev_stops
# ---> 26 connections = stop.get_departures_after(curr_time)
#      27 for connection in connections:
#      28     wait_seconds = (connection.arrival_time - curr_time).total_seconds()
#
# File c:\Users\noelf\OneDrive\Dokumente\programming-noel\ipynb\zurich-trams\tramnetwork.py:369, in TramStop.get_departures_after(self, time)
#     368 def get_departures_after(self, time: datetime) -> list[TramPath]:
# --> 369     return [
#     370         c for c in self.connections
#     371         if c.departure_times[0] >= time
#     372     ]
#
# File c:\Users\noelf\OneDrive\Dokumente\programming-noel\ipynb\zurich-trams\tramnetwork.py:371, in <listcomp>(.0)
#     368 def get_departures_after(self, time: datetime) -> list[TramPath]:
#     369     return [
#     370         c for c in self.connections
# --> 371         if c.departure_times[0] >= time
#     372     ]
#
# KeyboardInterrupt:

# %%
best_path.save("optimized-ttsp")
best_path.save_image("optimized-ttsp")
# Out:
# 'optimized-ttsp.2025-01-28--9-21-42.png'
